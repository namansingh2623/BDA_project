# %%
import pandas as pd
import os
import openpyxl

# %%
# Relative path to the Excel file (PRE PANDEMIC)
file_path = "2019-29/education.xlsx"
# Now the post pandemic path
file_path2 = "2023-33/education.xlsx"

# Load the workbook
# Prepandemic workbook
workbook = openpyxl.load_workbook(file_path)
# Postpandemic workbook
workbook2 = openpyxl.load_workbook(file_path2)

# Collection of the spreadsheet tabs we will be working with (PRE PANDEMIC)
table1 = workbook["Table 5.2"]
table2 = workbook["Table 5.3"]
table3 = workbook["Table 5.4"]

# Collection of spreadsheet tabs we will also be working with (POST PANDEMIC)
table1p = workbook["Table 5.2"]
table2p = workbook["Table 5.3"]
table3p = workbook["Table 5.4"]
# Note: post-pandemic spreadsheet has an additional data table Table 5.1, but since it is absent in the pre-pandemic tables, I didn't include it

# Function that processes and outputs all of our data
def processTable(sheet):
    # Loop through rows and columns to extract data neatly
    for row in sheet.iter_rows(min_row=1, max_row=sheet.max_row, min_col=1, max_col=sheet.max_column):
        row_values = [cell.value for cell in row]
        print(row_values)

# %%
# -- PRE PANDEMIC DATA --

# This data table is Table 5.2 Employment, wages, and projected change in employment by typical entry-level education (Employment in thousands)
# List indices are: Typical Entry level education, employment 2019, employment distribution % 2019, employment change % 2019-29, median annual wage
processTable(table1)
print("\n")
# Out:
# ['Table 5.2 Employment, wages, and projected change in employment by typical entry-level education \n(Employment in thousands)', None, None, None, None]
# ['Typical entry-level education', 'Employment, 2019', 'Employment distribution, percent, 2019', 'Employment change, percent, 2019-29', 'Median annual wage, 2020(1)']
# ['Total, all occupations', 162795.6, 100, 3.7, 41950]
# ['Doctoral or professional degree', 4412.8, 2.7, 5.9, 110200]
# ["Master's degree", 2633.9, 1.6, 15, 78210]
# ["Bachelor's degree", 36864.2, 22.6, 6.4, 77920]
# ["Associate's degree", 3601.6, 2.2, 6.2, 56590]
# ['Postsecondary nondegree award', 10093.2, 6.2, 5.6, 41520]
# ['Some college, no degree', 4085, 2.5, -0.1, 37770]
# ['High school diploma or equivalent', 62410, 38.3, 1.5, 39070]
# ['No formal educational credential', 38694.8, 23.8, 3.3, 27510]
# ['Footnotes:', None, None, None, None]
# ['(1) Data are from the Occupational Employment Statistics program, U.S. Bureau of Labor Statistics.  Wage data cover non-farm wage and salary workers and do not cover the self-employed, owners and partners in unincorporated firms, or household workers.', None, None, None, None]
# ['Note: The occupational employment and growth rates shown in this table include projected growth in all jobs from 2019-29, not just entry-level jobs. Entry-level education reflects 2019 requirements—BLS does not project educational requirements.', None, None, None, None]
# ['Source: Employment Projections program, U.S. Bureau of Labor Statistics', None, None, None, None]

# %%
import matplotlib.pyplot as plt

# Function to process and extract relevant rows
def extract_employment_data(sheet):
    data = []
    for row in sheet.iter_rows(min_row=1, max_row=sheet.max_row, min_col=1, max_col=sheet.max_column):
        row_values = [cell.value for cell in row]
        # Skip metadata rows
        if (
            not row_values[0] or  # Skip rows with no label
            row_values[0].startswith("Table") or  # Skip title row
            row_values[0] == "Typical entry-level education" or  # Skip header row
            row_values[0] in ("Footnotes:", "(1)") or  # Skip footnote rows
            row_values[0].startswith("Note:") or  # Skip notes
            row_values[0].startswith("Source:")  # Skip source
        ):
            continue
        # Ensure all data rows have meaningful values
        if row_values[1] is not None:  # Check if Employment, 2019 is valid
            data.append(row_values)
    return data

# Extract relevant data
processed_data = extract_employment_data(table1)

# Remove "Total, all occupations"
filtered_data = [row for row in processed_data if row[0] != "Total, all occupations"]

# Extract labels and employment values
labels = [row[0] for row in filtered_data]  # Column 0 (education levels)
employment_2019 = [row[1] for row in filtered_data]  # Column 1 (employment)

# Print extracted data
print("Labels:", labels)
print("Employment 2019:", employment_2019)

# Plot the graph
plt.figure(figsize=(12, 6))
plt.bar(labels, employment_2019, color='skyblue', edgecolor='black')
plt.title('Employment by Education Level in 2019 (Excluding Total, All Occupations)', fontsize=16)
plt.xlabel('Education Level', fontsize=14)
plt.ylabel('Employment (in thousands)', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Labels: ['Doctoral or professional degree', "Master's degree", "Bachelor's degree", "Associate's degree", 'Postsecondary nondegree award', 'Some college, no degree', 'High school diploma or equivalent', 'No formal educational credential']
# Employment 2019: [4412.8, 2633.9, 36864.2, 3601.6, 10093.2, 4085, 62410, 38694.8]

# %%
# Function to process and extract relevant rows
def extract_employment_distribution(sheet):
    data = []
    for row in sheet.iter_rows(min_row=1, max_row=sheet.max_row, min_col=1, max_col=sheet.max_column):
        row_values = [cell.value for cell in row]
        # Skip metadata rows
        if (
            not row_values[0] or  # Skip rows with no label
            row_values[0].startswith("Table") or  # Skip title row
            row_values[0] == "Typical entry-level education" or  # Skip header row
            row_values[0] in ("Footnotes:", "(1)") or  # Skip footnote rows
            row_values[0].startswith("Note:") or  # Skip notes
            row_values[0].startswith("Source:")  # Skip source
        ):
            continue
        # Ensure all data rows have meaningful values
        if row_values[2] is not None:  # Check if Employment distribution percent is valid
            data.append(row_values)
    return data

# Extract relevant data (employment distribution percent)
processed_data_distribution = extract_employment_distribution(table1)

# Remove "Total, all occupations"
filtered_data_distribution = [row for row in processed_data_distribution if row[0] != "Total, all occupations"]

# Extract labels and employment distribution percentage values
labels_distribution = [row[0] for row in filtered_data_distribution]  # Column 0 (education levels)
employment_distribution_2019 = [row[2] for row in filtered_data_distribution]  # Column 2 (employment distribution %)

# Print extracted data
print("Labels:", labels_distribution)
print("Employment Distribution Percent, 2019:", employment_distribution_2019)

# Plot the graph
plt.figure(figsize=(12, 6))
plt.bar(labels_distribution, employment_distribution_2019, color='skyblue', edgecolor='black')

# Adding title and labels
plt.title('Employment Distribution by Education Level in 2019', fontsize=16)
plt.xlabel('Education Level', fontsize=14)
plt.ylabel('Employment Distribution (%)', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# Labels: ['Doctoral or professional degree', "Master's degree", "Bachelor's degree", "Associate's degree", 'Postsecondary nondegree award', 'Some college, no degree', 'High school diploma or equivalent', 'No formal educational credential']
# Employment Distribution Percent, 2019: [2.7, 1.6, 22.6, 2.2, 6.2, 2.5, 38.3, 23.8]

# %%
import matplotlib.pyplot as plt

# Function to process and extract relevant rows
def extract_employment_change(sheet):
    data = []
    for row in sheet.iter_rows(min_row=1, max_row=sheet.max_row, min_col=1, max_col=sheet.max_column):
        row_values = [cell.value for cell in row]
        # Skip metadata rows
        if (
            not row_values[0] or  # Skip rows with no label
            row_values[0].startswith("Table") or  # Skip title row
            row_values[0] == "Typical entry-level education" or  # Skip header row
            row_values[0] in ("Footnotes:", "(1)") or  # Skip footnote rows
            row_values[0].startswith("Note:") or  # Skip notes
            row_values[0].startswith("Source:")  # Skip source
        ):
            continue
        # Ensure all data rows have meaningful values
        if row_values[3] is not None:  # Check if Employment change percent is valid
            data.append(row_values)
    return data

# Extract relevant data (employment change percent)
processed_data_change = extract_employment_change(table1)

# Remove "Total, all occupations"
filtered_data_change = [row for row in processed_data_change if row[0] != "Total, all occupations"]

# Extract labels and employment change percentage values
labels_change = [row[0] for row in filtered_data_change]  # Column 0 (education levels)
employment_change_percent_2019_29 = [row[3] for row in filtered_data_change]  # Column 3 (employment change percent 2019-29)

# Print extracted data
print("Labels:", labels_change)
print("Employment Change Percent, 2019-29:", employment_change_percent_2019_29)

# Plot the graph
plt.figure(figsize=(12, 6))
plt.bar(labels_change, employment_change_percent_2019_29, color='lightcoral', edgecolor='black')

# Adding title and labels
plt.title('Employment Change by Education Level (2019-29)', fontsize=16)
plt.xlabel('Education Level', fontsize=14)
plt.ylabel('Employment Change (%) 2019-29', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# Labels: ['Doctoral or professional degree', "Master's degree", "Bachelor's degree", "Associate's degree", 'Postsecondary nondegree award', 'Some college, no degree', 'High school diploma or equivalent', 'No formal educational credential']
# Employment Change Percent, 2019-29: [5.9, 15, 6.4, 6.2, 5.6, -0.1, 1.5, 3.3]

# %%
import matplotlib.pyplot as plt

# Function to process and extract relevant rows for Median Annual Wage
def extract_median_wage(sheet):
    data = []
    for row in sheet.iter_rows(min_row=1, max_row=sheet.max_row, min_col=1, max_col=sheet.max_column):
        row_values = [cell.value for cell in row]
        # Skip metadata rows, these rows don't really contribute to data.
        if (
            not row_values[0] or  # Skip rows with no label
            row_values[0].startswith("Table") or  # Skip title row
            row_values[0] == "Typical entry-level education" or  # Skip header row
            row_values[0] in ("Footnotes:", "(1)") or  # Skip footnote rows
            row_values[0].startswith("Note:") or  # Skip notes
            row_values[0].startswith("Source:")  # Skip source
        ):
            continue
        # Ensure all data rows have meaningful values
        if row_values[4] is not None:  # Check if Median Annual Wage is valid
            data.append(row_values)
    return data

# Extract relevant data (Median Annual Wage)
processed_data_wage = extract_median_wage(table1)

# Remove "Total, all occupations", throws off our data.
filtered_data_wage = [row for row in processed_data_wage if row[0] != "Total, all occupations"]

# Extract labels and Median Annual Wage values
labels_wage = [row[0] for row in filtered_data_wage]  # Column 0 (education levels)
median_annual_wage = [row[4] for row in filtered_data_wage]  # Column 4 (Median Annual Wage)

# Print extracted data
print("Labels:", labels_wage)
print("Median Annual Wage:", median_annual_wage)

# Plot the graph
plt.figure(figsize=(12, 6))
plt.bar(labels_wage, median_annual_wage, color='lightgreen', edgecolor='black')

# Adding title and labels
plt.title('Median Annual Wage by Education Level (2020)', fontsize=16)
plt.xlabel('Education Level', fontsize=14)
plt.ylabel('Median Annual Wage (USD)', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# Labels: ['Doctoral or professional degree', "Master's degree", "Bachelor's degree", "Associate's degree", 'Postsecondary nondegree award', 'Some college, no degree', 'High school diploma or equivalent', 'No formal educational credential']
# Median Annual Wage: [110200, 78210, 77920, 56590, 41520, 37770, 39070, 27510]

# %%
# This data table is Table 5.3 Educational attainment for workers 25 years and older by detailed occupation, 2019
# List indices are: 2019 National Employment Matrix title, 2019 National Employment Matrix code,
#high school diploma num, some college no degree num, associates degree num, bachelors degree num, masters degree num, doctorate num
processTable(table2)
print("\n")

# %%
# Function to process and extract relevant rows for a specific title
def extract_total_occupation_data(sheet):
    for row in sheet.iter_rows(min_row=1, max_row=sheet.max_row, min_col=1, max_col=sheet.max_column):
        row_values = [cell.value for cell in row]
        # Look for the row with "Total, all occupations"
        if row_values[0] == "Total, all occupations":
            return row_values[2:]  # Return data starting from index 2 (excluding matrix code)

# Extracting data
total_occupation_data = extract_total_occupation_data(table2)

# Education levels corresponding to the data
education_levels = [
    "Less than high school diploma",
    "High school diploma or equivalent",
    "Some college, no degree",
    "Associate's degree",
    "Bachelor's degree",
    "Master's degree",
    "Doctoral or professional degree",
]

# Plot the bar graph
plt.figure(figsize=(12, 6))
plt.bar(education_levels, total_occupation_data, color='skyblue', edgecolor='black')
plt.title("Educational Attainment Distribution Percentage (Total, All Occupations, 2019)", fontsize=16)
plt.xlabel("Education Level", fontsize=14)
plt.ylabel("Percentage of Workers", fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# This data table is Table 5.4 Education and training assignments by detailed occupation, 2019
processTable(table3)
print("\n")

# %%
# -- POST PANDEMIC DATA --

# This data table is Table 5.2 Employment, wages, and projected change in employment by typical entry-level education (Employment in thousands)
# List indices are: Typical Entry level education, employment 2033, employment distribution % 2023, employment change % 2023-33, median annual wage
processTable(table1p)
print("\n")
# Out:
# ['Table 5.2 Employment, wages, and projected change in employment by typical entry-level education \n(Employment in thousands)', None, None, None, None]
# ['Typical entry-level education', 'Employment, 2019', 'Employment distribution, percent, 2019', 'Employment change, percent, 2019-29', 'Median annual wage, 2020(1)']
# ['Total, all occupations', 162795.6, 100, 3.7, 41950]
# ['Doctoral or professional degree', 4412.8, 2.7, 5.9, 110200]
# ["Master's degree", 2633.9, 1.6, 15, 78210]
# ["Bachelor's degree", 36864.2, 22.6, 6.4, 77920]
# ["Associate's degree", 3601.6, 2.2, 6.2, 56590]
# ['Postsecondary nondegree award', 10093.2, 6.2, 5.6, 41520]
# ['Some college, no degree', 4085, 2.5, -0.1, 37770]
# ['High school diploma or equivalent', 62410, 38.3, 1.5, 39070]
# ['No formal educational credential', 38694.8, 23.8, 3.3, 27510]
# ['Footnotes:', None, None, None, None]
# ['(1) Data are from the Occupational Employment Statistics program, U.S. Bureau of Labor Statistics.  Wage data cover non-farm wage and salary workers and do not cover the self-employed, owners and partners in unincorporated firms, or household workers.', None, None, None, None]
# ['Note: The occupational employment and growth rates shown in this table include projected growth in all jobs from 2019-29, not just entry-level jobs. Entry-level education reflects 2019 requirements—BLS does not project educational requirements.', None, None, None, None]
# ['Source: Employment Projections program, U.S. Bureau of Labor Statistics', None, None, None, None]

# %%
# This data table is Table 5.3 Educational attainment for workers 25 years and older by detailed occupation, 2023
# List indices are: 2019 National Employment Matrix title, 2019 National Employment Matrix code,
#high school diploma num, some college no degree num, associates degree num, bachelors degree num, masters degree num, doctorate num
processTable(table2p)
print("\n")
# Out:
# ['Table 5.3 Educational attainment for workers 25 years and older by detailed occupation, 2019', None, None, None, None, None, None, None, None]
# ['2019 National Employment Matrix title', '2019 National Employment Matrix code', 'Less than high school diploma', 'High school diploma or equivalent', 'Some college, no degree', "Associate's degree", "Bachelor's degree", "Master's degree", 'Doctoral or professional degree']
# ['Total, all occupations', '00-0000', 7.9, 23.6, 20, 9.5, 23.9, 10.6, 4.4]
# ['Chief executives(1)', '11-1011', 1.6, 8, 13.9, 4.8, 41, 24.1, 6.5]
# ['General and operations managers', '11-1021', 2.6, 16.9, 24.3, 10, 33.4, 11.1, 1.7]
# ['Legislators(1)', '11-1031', 1.6, 8, 13.9, 4.8, 41, 24.1, 6.5]
# ['Advertising and promotions managers', '11-2011', 1.1, 1.8, 10.6, 6.2, 65.6, 12.7, 2]
# ['Marketing managers', '11-2021', 0.8, 4.1, 8.7, 5, 56.2, 23.6, 1.7]
# ['Sales managers', '11-2022', 1.3, 11, 19.5, 9, 46.3, 11.8, 1.1]
# ['Public relations and fundraising managers', '11-2030', 0.1, 3.3, 5.1, 3.9, 55.4, 28.5, 3.7]
# ['Administrative services and facilities managers(1)', '11-3010', 2.1, 18.4, 22.8, 12, 32.8, 10.3, 1.5]
# ['Computer and information systems managers', '11-3021', 0.5, 4.1, 12.6, 8, 46.3, 25.6, 2.9]
# ['Financial managers', '11-3031', 1, 10.1, 17.2, 7.6, 42.3, 19.5, 2.4]
# ['Industrial production managers', '11-3051', 4, 20.8, 20.7, 9.1, 32.7, 11.2, 1.4]
# ['Purchasing managers', '11-3061', 1.8, 11.5, 17.3, 7.9, 42.6, 16.6, 2.3]
# ['Transportation, storage, and distribution managers', '11-3071', 5, 28.6, 24.8, 9.9, 24.4, 6.8, 0.4]
# ['Compensation and benefits managers', '11-3111', 0.9, 12.3, 14, 3.2, 50.2, 16.8, 2.6]
# ['Human resources managers', '11-3121', 0.7, 7.6, 14.1, 7.9, 43.4, 23.6, 2.9]
# ['Training and development managers', '11-3131', 0.9, 7.4, 16, 7.5, 40.5, 23.5, 4.2]
# ['Farmers, ranchers, and other agricultural managers', '11-9013', 10.1, 33.9, 19.1, 11.1, 21.4, 3.4, 1.1]
# ['Construction managers', '11-9021', 6.4, 27.8, 22.6, 8.9, 27.5, 5.7, 0.9]
# ['Education and childcare administrators, preschool and daycare(1)', '11-9031', 0.6, 4.5, 7, 4.4, 25.4, 44.3, 13.8]
# ['Education administrators, kindergarten through secondary(1)', '11-9032', 0.6, 4.5, 7, 4.4, 25.4, 44.3, 13.8]
# ['Education administrators, postsecondary(1)', '11-9033', 0.6, 4.5, 7, 4.4, 25.4, 44.3, 13.8]
# ['Education administrators, all other(1)', '11-9039', 0.6, 4.5, 7, 4.4, 25.4, 44.3, 13.8]
# ['Architectural and engineering managers', '11-9041', 0.2, 4.5, 7, 4.9, 46.7, 31.3, 5.4]
# ['Food service managers', '11-9051', 10.1, 28.2, 26, 9.8, 22.1, 3.3, 0.6]
# ['Gambling managers(1)', '11-9071', 2.2, 19, 26.9, 10.1, 31.1, 10.2, 0.6]
# ['Lodging managers', '11-9081', 5, 15.4, 23.7, 9.3, 36.8, 8.6, 1.1]
# ['Medical and health services managers', '11-9111', 1.2, 8, 14.8, 11.2, 32, 25.6, 7.2]
# ['Natural sciences managers', '11-9121', 0, 3.5, 3.6, 4, 35, 30.7, 23.1]
# ['Postmasters and mail superintendents(1)', '11-9131', 3.5, 15.9, 17.8, 7.5, 34.6, 17.1, 3.6]
# ['Property, real estate, and community association managers', '11-9141', 4.1, 19.1, 24.1, 10, 31.9, 8.7, 2.1]
# ['Social and community service managers', '11-9151', 1, 6.8, 12.8, 5.8, 39.4, 28.9, 5.3]
# ['Emergency management directors', '11-9161', 0, 6.9, 13.6, 7.8, 37.3, 32.2, 2.2]
# ['Funeral home managers(1)', '11-9171', 3.5, 15.9, 17.8, 7.5, 34.6, 17.1, 3.6]
# ['Personal service managers, all other; entertainment and recreation managers, except gambling; and managers, all other(1)', '11-9198', 3.1, 14.9, 17.4, 7.4, 36.1, 17.7, 3.4]
# ['Agents and business managers of artists, performers, and athletes', '13-1011', 2.6, 7.3, 17.3, 4.4, 50.3, 13.1, 5]
# ['Buyers and purchasing agents(1)', '13-1020', 2.7, 20.3, 23.8, 9.8, 34.4, 8, 0.9]
# ['Claims adjusters, examiners, and investigators(1)', '13-1031', 1, 13.7, 22.8, 11, 42.7, 6.8, 2]
# ['Insurance appraisers, auto damage(1)', '13-1032', 1, 13.7, 22.8, 11, 42.7, 6.8, 2]
# ['Compliance officers', '13-1041', 1.3, 8.9, 17, 8.5, 40.2, 18.1, 6]
# ['Cost estimators', '13-1051', 2.9, 22.2, 27.6, 9.8, 31.4, 5.7, 0.4]
# ['Human resources specialists(1)', '13-1071', 0.9, 8.8, 16.3, 8.3, 46.2, 17.6, 1.9]
# ['Farm labor contractors(1)', '13-1074', 0.9, 8.8, 16.3, 8.3, 46.2, 17.6, 1.9]
# ['Labor relations specialists(1)', '13-1075', 0.9, 8.8, 16.3, 8.3, 46.2, 17.6, 1.9]
# ['Logisticians', '13-1081', 2.9, 16.8, 22.1, 13.8, 33, 10.8, 0.6]
# ['Management analysts', '13-1111', 0.9, 4.8, 11.2, 5.2, 44.2, 28.1, 5.7]
# ['Meeting, convention, and event planners', '13-1121', 1.2, 8.9, 15.4, 9.2, 52.7, 12.1, 0.6]
# ['Fundraisers', '13-1131', 0.3, 1.7, 7.4, 1.8, 50.2, 33.9, 4.8]
# ['Compensation, benefits, and job analysis specialists', '13-1141', 1, 14.3, 18.8, 12, 40.8, 11.4, 1.8]
# ['Training and development specialists', '13-1151', 2.3, 13.9, 22.1, 8.9, 33.2, 17.5, 2.1]
# ['Market research analysts and marketing specialists', '13-1161', 0.7, 4.9, 10.6, 4.9, 54.5, 21.6, 2.7]
# ['Project management specialists and business operations specialists, all other(1)', '13-1198', 1, 8.3, 14.4, 7.8, 44.4, 21.5, 2.6]
# ['Accountants and auditors', '13-2011', 0, 2.5, 4.3, 7.3, 59, 23.7, 3.1]
# ['Property appraisers and assessors', '13-2020', 0.6, 11.3, 22.3, 8.8, 44.5, 10.2, 2.1]
# ['Budget analysts', '13-2031', 0, 4.4, 11.1, 6.4, 42, 33.5, 2.6]
# ['Credit analysts', '13-2041', 0, 10.3, 13.6, 8.5, 49.8, 16.1, 1.7]
# ['Personal financial advisors', '13-2052', 0.2, 3.3, 9.3, 4.4, 54.2, 22.8, 5.8]
# ['Insurance underwriters', '13-2053', 1.4, 10.7, 17.1, 8.8, 50.1, 9.8, 2.2]
# ['Financial examiners', '13-2061', 0.1, 5.1, 7.7, 5.3, 55.1, 21.5, 5.3]
# ['Credit counselors(1)', '13-2071', 0.7, 13.8, 22.5, 9.8, 41.8, 10.5, 1]
# ['Loan officers(1)', '13-2072', 0.7, 13.8, 22.5, 9.8, 41.8, 10.5, 1]
# ['Tax examiners and collectors, and revenue agents', '13-2081', 0.8, 18.2, 21.9, 10.7, 37.2, 9.7, 1.5]
# ['Tax preparers', '13-2082', 3, 11.7, 22.3, 10.9, 31.3, 14.3, 6.6]
# ['Financial and investment analysts, financial risk specialists, and financial specialists, all other(1)', '13-2098', 0.5, 4.5, 8.2, 3.4, 51.2, 29.3, 2.9]
# ['Computer systems analysts', '15-1211', 0.3, 5.1, 12.6, 8.2, 48.4, 22.9, 2.5]
# ['Information security analysts', '15-1212', 0.9, 4.2, 15.6, 10.1, 43.3, 24, 1.9]
# ['Computer and information research scientists', '15-1221', 0, 0.5, 4.2, 0.9, 35.7, 37.9, 20.8]
# ['Computer network support specialists(1)', '15-1231', 1.1, 10.9, 23.7, 15.5, 37.2, 10.2, 1.4]
# ['Computer user support specialists(1)', '15-1232', 1.1, 10.9, 23.7, 15.5, 37.2, 10.2, 1.4]
# ['Computer network architects', '15-1241', 0.7, 6, 21.5, 16.2, 40.3, 13.9, 1.4]
# ['Network and computer systems administrators', '15-1244', 0.7, 6.4, 20.6, 16.8, 40.8, 13.3, 1.5]
# ['Database administrators and architects(1)', '15-1245', 0.5, 7.3, 12.1, 6.5, 43.9, 27.3, 2.4]
# ['Computer programmers', '15-1251', 1.2, 5.2, 13.1, 7.3, 49.7, 21, 2.4]
# ['Software developers and software quality assurance analysts and testers(1)', '15-1256', 0.5, 1.8, 7.3, 4.4, 50.5, 31.2, 4.2]
# ['Web developers and digital interface designers(1)', '15-1257', 0.8, 5.1, 14.4, 9, 55.1, 14.8, 0.9]
# ['Computer occupations, all other(1)', '15-1299', 1.1, 8.4, 17, 10.2, 42.6, 19.1, 1.7]
# ['Actuaries', '15-2011', 0, 0, 0.9, 0.5, 66.3, 20.4, 11.9]
# ['Mathematicians(1)', '15-2021', 0.6, 3.8, 7.8, 3.4, 37, 34.8, 12.7]
# ['Operations research analysts', '15-2031', 1.1, 6, 12, 6.4, 40.6, 29, 4.9]
# ['Statisticians(1)', '15-2041', 0.6, 3.8, 7.8, 3.4, 37, 34.8, 12.7]
# ['Data scientists and mathematical science occupations, all other(1)', '15-2098', 0.6, 3.8, 7.8, 3.4, 37, 34.8, 12.7]
# ['Architects, except landscape and naval', '17-1011', 0.4, 1.4, 3.6, 2.7, 46, 37.7, 8.2]
# ['Landscape architects', '17-1012', 1, 5.4, 5.8, 4.1, 59.2, 20.4, 4.1]
# ['Cartographers and photogrammetrists(1)', '17-1021', 0.1, 2.8, 10.8, 11.8, 62.8, 8.6, 3]
# ['Surveyors(1)', '17-1022', 0.1, 2.8, 10.8, 11.8, 62.8, 8.6, 3]
# ['Aerospace engineers', '17-2011', 0.1, 1.6, 4.6, 3.6, 51.2, 32, 6.9]
# ['Agricultural engineers(1)', '17-2021', 0.5, 6.4, 3.8, 7.6, 41, 29, 11.7]
# ['Bioengineers and biomedical engineers(1)', '17-2031', 0.5, 6.4, 3.8, 7.6, 41, 29, 11.7]
# ['Chemical engineers', '17-2041', 0.7, 1.6, 5, 4, 61.5, 21.6, 5.7]
# ['Civil engineers', '17-2051', 0.7, 2.5, 4.4, 3.4, 58.8, 25.8, 4.4]
# ['Computer hardware engineers', '17-2061', 0.1, 4.2, 6.3, 8.3, 52.4, 23.6, 5.2]
# ['Electrical engineers(1)', '17-2071', 0.2, 3.3, 5.7, 6.3, 50.4, 27.5, 6.7]
# ['Electronics engineers, except computer(1)', '17-2072', 0.2, 3.3, 5.7, 6.3, 50.4, 27.5, 6.7]
# ['Environmental engineers', '17-2081', 0.6, 4.1, 2.2, 3.4, 49, 36.5, 4.3]
# ['Health and safety engineers, except mining safety engineers and inspectors(1)', '17-2111', 0.9, 6.4, 11.1, 7.9, 52.4, 18.6, 2.8]
# ['Industrial engineers(1)', '17-2112', 0.9, 6.4, 11.1, 7.9, 52.4, 18.6, 2.8]
# ['Marine engineers and naval architects', '17-2121', 5.5, 13, 5.3, 3.9, 51.8, 19, 1.5]
# ['Materials engineers', '17-2131', 0.5, 4.3, 8.9, 8.7, 49, 20.6, 7.8]
# ['Mechanical engineers', '17-2141', 0.9, 3.6, 6.5, 8, 55.7, 21, 4.2]
# ['Mining and geological engineers, including mining safety engineers(1)', '17-2151', 1.5, 4, 3.8, 4.1, 53.1, 24.3, 9.2]
# ['Nuclear engineers(1)', '17-2161', 0.6, 3.2, 6.8, 7.2, 49.5, 24.9, 7.7]
# ['Petroleum engineers(1)', '17-2171', 1.5, 4, 3.8, 4.1, 53.1, 24.3, 9.2]
# ['Engineers, all other(1)', '17-2199', 0.6, 3.2, 6.8, 7.2, 49.5, 24.9, 7.7]
# ['Architectural and civil drafters', '17-3011', 2.6, 9.2, 20.7, 32.7, 27.6, 6.2, 1.1]
# ['Electrical and electronics drafters(1)', '17-3012', 2, 12.7, 22.2, 33, 23.6, 5.1, 1.4]
# ['Mechanical drafters(1)', '17-3013', 2, 12.7, 22.2, 33, 23.6, 5.1, 1.4]
# ['Drafters, all other(1)', '17-3019', 2, 12.7, 22.2, 33, 23.6, 5.1, 1.4]
# ['Aerospace engineering and operations technologists and technicians(1)', '17-3021', 4.5, 24.2, 30.5, 20.2, 17.2, 2.6, 0.8]
# ['Civil engineering technologists and technicians(1)', '17-3022', 4.5, 24.2, 30.5, 20.2, 17.2, 2.6, 0.8]
# ['Electrical and electronic engineering technologists and technicians', '17-3023', 2.8, 18.2, 33.3, 30.9, 13.5, 1.2, 0.2]
# ['Electro-mechanical and mechatronics technologists and technicians(1)', '17-3024', 4.5, 24.2, 30.5, 20.2, 17.2, 2.6, 0.8]
# ['Environmental engineering technologists and technicians(1)', '17-3025', 4.5, 24.2, 30.5, 20.2, 17.2, 2.6, 0.8]
# ['Industrial engineering technologists and technicians(1)', '17-3026', 4.5, 24.2, 30.5, 20.2, 17.2, 2.6, 0.8]
# ['Mechanical engineering technologists and technicians(1)', '17-3027', 4.5, 24.2, 30.5, 20.2, 17.2, 2.6, 0.8]
# ['Surveying and mapping technicians', '17-3031', 3.4, 29.3, 33.1, 24.6, 7.8, 0.9, 0.8]
# ['Calibration technologists and technicians and engineering technologists and technicians, except drafters, all other(1)', '17-3098', 4.5, 24.2, 30.5, 20.2, 17.2, 2.6, 0.8]
# ['Animal scientists(1)', '19-1011', 0, 0, 0, 0, 61.6, 23.7, 14.7]
# ['Food scientists and technologists(1)', '19-1012', 0, 0, 0, 0, 61.6, 23.7, 14.7]
# ['Soil and plant scientists(1)', '19-1013', 0, 0, 0, 0, 61.6, 23.7, 14.7]
# ['Biochemists and biophysicists(1)', '19-1021', 0, 0, 0, 0, 44, 31.5, 24.5]
# ['Microbiologists(1)', '19-1022', 0, 0, 0, 0, 44, 31.5, 24.5]
# ['Zoologists and wildlife biologists(1)', '19-1023', 0, 0, 0, 0, 44, 31.5, 24.5]
# ['Biological scientists, all other(1)', '19-1029', 0, 0, 0, 0, 44, 31.5, 24.5]
# ['Conservation scientists(1)', '19-1031', 0, 0, 0, 0, 77.7, 19.2, 3.1]
# ['Foresters(1)', '19-1032', 0, 0, 0, 0, 77.7, 19.2, 3.1]
# ['Epidemiologists(1)', '19-1041', 0.5, 0.4, 0.4, 0.7, 21.9, 27, 49.1]
# ['Medical scientists, except epidemiologists(1)', '19-1042', 0.5, 0.4, 0.4, 0.7, 21.9, 27, 49.1]
# ['Life scientists, all other(1)', '19-1099', 0.5, 0.4, 0.4, 0.7, 21.9, 27, 49.1]
# ['Astronomers(1)', '19-2011', 0, 0, 0, 0, 23.8, 15.3, 60.9]
# ['Physicists(1)', '19-2012', 0, 0, 0, 0, 23.8, 15.3, 60.9]
# ['Atmospheric and space scientists', '19-2021', 0, 0.4, 6.2, 2.2, 61.7, 20.2, 9.4]
# ['Chemists(1)', '19-2031', 0.1, 1.2, 2.6, 1.9, 52.5, 21.6, 20.1]
# ['Materials scientists(1)', '19-2032', 0.1, 1.2, 2.6, 1.9, 52.5, 21.6, 20.1]
# ['Environmental scientists and specialists, including health', '19-2041', 0, 0, 0, 0, 63.8, 31.6, 4.6]
# ['Geoscientists, except hydrologists and geographers(1)', '19-2042', 0, 0, 0, 0, 45.8, 40.5, 13.7]
# ['Hydrologists(1)', '19-2043', 0, 0, 0, 0, 45.8, 40.5, 13.7]
# ['Physical scientists, all other', '19-2099', 0, 0, 0, 0, 26.8, 22.8, 50.4]
# ['Economists', '19-3011', 0, 0, 0, 0, 23, 40, 37]
# ['Survey researchers(1)', '19-3022', 1.1, 1, 3.9, 4.9, 32, 42.3, 14.7]
# ['Clinical, counseling, and school psychologists(1)', '19-3031', 0, 0, 0, 0, 8.9, 42.9, 48.2]
# ['Industrial-organizational psychologists(1)', '19-3032', 0, 0, 0, 0, 7.6, 39.4, 53]
# ['Psychologists, all other(1)', '19-3039', 0, 0, 0, 0, 7.6, 39.4, 53]
# ['Sociologists(1)', '19-3041', 1.1, 1, 3.9, 4.9, 32, 42.3, 14.7]
# ['Urban and regional planners', '19-3051', 0, 0, 0, 0, 43.2, 52.4, 4.4]
# ['Anthropologists and archeologists(1)', '19-3091', 1.1, 1, 3.9, 4.9, 32, 42.3, 14.7]
# ['Geographers(1)', '19-3092', 1.1, 1, 3.9, 4.9, 32, 42.3, 14.7]
# ['Historians(1)', '19-3093', 1.1, 1, 3.9, 4.9, 32, 42.3, 14.7]
# ['Political scientists(1)', '19-3094', 1.1, 1, 3.9, 4.9, 32, 42.3, 14.7]
# ['Social scientists and related workers, all other(1)', '19-3099', 1.1, 1, 3.9, 4.9, 32, 42.3, 14.7]
# ['Agricultural and food science technicians', '19-4010', 4.7, 27, 24.3, 16.2, 22, 4.2, 1.7]
# ['Biological technicians', '19-4021', 3.2, 20, 17.9, 11.5, 34.5, 8.3, 4.7]
# ['Chemical technicians', '19-4031', 3, 22.3, 22.2, 11.7, 34.4, 4, 2.4]
# ['Environmental science and protection technicians, including health(1)', '19-4042', 1.3, 21, 19.3, 13.7, 35.5, 7.8, 1.4]
# ['Geological and hydrologic technicians(1)', '19-4045', 1.3, 21, 19.3, 13.7, 35.5, 7.8, 1.4]
# ['Nuclear technicians(1)', '19-4051', 1.3, 21, 19.3, 13.7, 35.5, 7.8, 1.4]
# ['Social science research assistants(1)', '19-4061', 3.1, 14.7, 23.4, 13.7, 31.9, 10.7, 2.6]
# ['Forest and conservation technicians(1)', '19-4071', 3.1, 14.7, 23.4, 13.7, 31.9, 10.7, 2.6]
# ['Forensic science technicians(1)', '19-4092', 3.1, 14.7, 23.4, 13.7, 31.9, 10.7, 2.6]
# ['Life, physical, and social science technicians, all other(1)', '19-4099', 2.9, 15.4, 22.9, 13.7, 32.3, 10.3, 2.4]
# ['Occupational health and safety specialists(1)', '19-5011', 2, 15, 22.5, 11.8, 33.7, 13.5, 1.4]
# ['Occupational health and safety technicians(1)', '19-5012', 2, 15, 22.5, 11.8, 33.7, 13.5, 1.4]
# ['Educational, guidance, and career counselors and advisors', '21-1012', 1, 4.6, 5, 2.6, 21.3, 60.7, 4.7]
# ['Marriage and family therapists', '21-1013', 0.4, 4.5, 5.1, 3.7, 14.1, 63, 9.2]
# ['Rehabilitation counselors', '21-1015', 2.3, 7.2, 14.4, 11.8, 28.3, 35, 0.9]
# ['Substance abuse, behavioral disorder, and mental health counselors(1)', '21-1018', 1, 4, 8.5, 6, 25.3, 51, 4.2]
# ['Counselors, all other', '21-1019', 1.2, 7, 10.2, 6.3, 29.3, 40.9, 5.2]
# ['Child, family, and school social workers', '21-1021', 2.5, 5.7, 9.1, 6, 35.7, 39.2, 1.9]
# ['Healthcare social workers', '21-1022', 3.7, 12.1, 14.6, 7.7, 26.1, 33.1, 2.7]
# ['Mental health and substance abuse social workers', '21-1023', 0, 2.2, 3.2, 0.8, 12.8, 78.7, 2.3]
# ['Social workers, all other', '21-1029', 1.1, 4.2, 7.9, 5.9, 39.2, 39.5, 2.3]
# ['Health education specialists(1)', '21-1091', 2.3, 9.3, 16.5, 10.2, 36.4, 21.6, 3.7]
# ['Probation officers and correctional treatment specialists', '21-1092', 1.3, 2.5, 7.7, 4.2, 66.3, 16.6, 1.4]
# ['Social and human service assistants', '21-1093', 2.2, 14.2, 21.8, 12.6, 34.7, 13.1, 1.4]
# ['Community health workers(1)', '21-1094', 2.3, 9.3, 16.5, 10.2, 36.4, 21.6, 3.7]
# ['Community and social service specialists, all other(1)', '21-1099', 2.3, 9.3, 16.5, 10.2, 36.4, 21.6, 3.7]
# ['Clergy', '21-2011', 2.4, 6.3, 10.5, 5, 25.5, 35.9, 14.4]
# ['Directors, religious activities and education', '21-2021', 1.3, 7.7, 15.9, 8.3, 41.4, 21.1, 4.4]
# ['Religious workers, all other', '21-2099', 1.8, 14.1, 19.4, 9.3, 35.8, 16.7, 2.9]
# ['Lawyers(1)', '23-1011', 0.2, 0.6, 0.8, 0.4, 5.5, 3.7, 88.8]
# ['Judicial law clerks', '23-1012', 0, 2.8, 10.8, 6.6, 17.1, 7, 55.7]
# ['Administrative law judges, adjudicators, and hearing officers(1)', '23-1021', 0.2, 0.6, 0.8, 0.4, 5.5, 3.7, 88.8]
# ['Arbitrators, mediators, and conciliators(1)', '23-1022', 0.2, 0.6, 0.8, 0.4, 5.5, 3.7, 88.8]
# ['Judges, magistrate judges, and magistrates(1)', '23-1023', 0.2, 0.6, 0.8, 0.4, 5.5, 3.7, 88.8]
# ['Paralegals and legal assistants', '23-2011', 0.7, 10.7, 23.1, 20.1, 35.6, 7.1, 2.8]
# ['Title examiners, abstractors, and searchers', '23-2093', 3.8, 21.9, 26.2, 12.9, 24.8, 5.2, 5.1]
# ['Legal support workers, all other', '23-2099', 1.9, 11.7, 15.9, 9, 45.9, 11.5, 4.1]
# ['Business teachers, postsecondary(1)', '25-1011', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Computer science teachers, postsecondary(1)', '25-1021', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Mathematical science teachers, postsecondary(1)', '25-1022', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Architecture teachers, postsecondary(1)', '25-1031', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Engineering teachers, postsecondary(1)', '25-1032', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Agricultural sciences teachers, postsecondary(1)', '25-1041', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Biological science teachers, postsecondary(1)', '25-1042', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Forestry and conservation science teachers, postsecondary(1)', '25-1043', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Atmospheric, earth, marine, and space sciences teachers, postsecondary(1)', '25-1051', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Chemistry teachers, postsecondary(1)', '25-1052', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Environmental science teachers, postsecondary(1)', '25-1053', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Physics teachers, postsecondary(1)', '25-1054', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Anthropology and archeology teachers, postsecondary(1)', '25-1061', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Area, ethnic, and cultural studies teachers, postsecondary(1)', '25-1062', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Economics teachers, postsecondary(1)', '25-1063', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Geography teachers, postsecondary(1)', '25-1064', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Political science teachers, postsecondary(1)', '25-1065', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Psychology teachers, postsecondary(1)', '25-1066', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Sociology teachers, postsecondary(1)', '25-1067', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Social sciences teachers, postsecondary, all other(1)', '25-1069', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Health specialties teachers, postsecondary(1)', '25-1071', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Nursing instructors and teachers, postsecondary(1)', '25-1072', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Education teachers, postsecondary(1)', '25-1081', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Library science teachers, postsecondary(1)', '25-1082', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Criminal justice and law enforcement teachers, postsecondary(1)', '25-1111', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Law teachers, postsecondary(1)', '25-1112', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Social work teachers, postsecondary(1)', '25-1113', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Art, drama, and music teachers, postsecondary(1)', '25-1121', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Communications teachers, postsecondary(1)', '25-1122', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['English language and literature teachers, postsecondary(1)', '25-1123', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Foreign language and literature teachers, postsecondary(1)', '25-1124', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['History teachers, postsecondary(1)', '25-1125', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Philosophy and religion teachers, postsecondary(1)', '25-1126', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Family and consumer sciences teachers, postsecondary(1)', '25-1192', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Recreation and fitness studies teachers, postsecondary(1)', '25-1193', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Career/technical education teachers, postsecondary(1)', '25-1194', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Postsecondary teachers, all other(1)', '25-1199', 0.7, 1.6, 1.9, 2, 14.7, 32.1, 47.1]
# ['Preschool teachers, except special education(1)', '25-2011', 1.4, 11.8, 19.1, 12.5, 36.3, 17.7, 1.3]
# ['Kindergarten teachers, except special education(1)', '25-2012', 1.4, 11.8, 19.1, 12.5, 36.3, 17.7, 1.3]
# ['Elementary school teachers, except special education(1)', '25-2021', 0, 0, 3, 2.4, 44.5, 46.1, 4]
# ['Middle school teachers, except special and career/technical education(1)', '25-2022', 0, 0, 3, 2.4, 44.5, 46.1, 4]
# ['Career/technical education teachers, middle school(1)', '25-2023', 0, 0, 3, 2.4, 44.5, 46.1, 4]
# ['Secondary school teachers, except special and career/technical education(1)', '25-2031', 0, 0, 2.1, 1.4, 40.3, 51.1, 5.1]
# ['Career/technical education teachers, secondary school(1)', '25-2032', 0, 0, 2.1, 1.4, 40.3, 51.1, 5.1]
# ['Special education teachers, preschool(1)', '25-2051', 0.3, 3.4, 4.5, 2.7, 33.1, 52.1, 3.8]
# ['Special education teachers, kindergarten and elementary school(1)', '25-2052', 0.3, 3.4, 4.5, 2.7, 33.1, 52.1, 3.8]
# ['Special education teachers, middle school(1)', '25-2057', 0.3, 3.4, 4.5, 2.7, 33.1, 52.1, 3.8]
# ['Special education teachers, secondary school(1)', '25-2058', 0.3, 3.4, 4.5, 2.7, 33.1, 52.1, 3.8]
# ['Special education teachers, all other(1)', '25-2059', 0.3, 3.4, 4.5, 2.7, 33.1, 52.1, 3.8]
# ['Adult basic education, adult secondary education, and English as a Second Language instructors(1)', '25-3011', 1.9, 11, 17.5, 7.9, 37.1, 19.9, 4.7]
# ['Self-enrichment teachers(1)', '25-3021', 1.9, 11, 17.5, 7.9, 37.1, 19.9, 4.7]
# ['Substitute teachers, short-term(1)', '25-3031', 1.9, 11, 17.5, 7.9, 37.1, 19.9, 4.7]
# ['Tutors and teachers and instructors, all other', '25-3097', 0.4, 4, 9.7, 8, 42.6, 30, 5.4]
# ['Archivists(1)', '25-4011', 1.5, 6.4, 9.7, 3.9, 36.2, 36.6, 5.7]
# ['Curators(1)', '25-4012', 1.5, 6.4, 9.7, 3.9, 36.2, 36.6, 5.7]
# ['Museum technicians and conservators(1)', '25-4013', 1.5, 6.4, 9.7, 3.9, 36.2, 36.6, 5.7]
# ['Librarians and media collections specialists', '25-4022', 0.2, 1.8, 7.7, 3.5, 23.4, 57.9, 5.5]
# ['Library technicians', '25-4031', 2.8, 29.5, 18.7, 7.2, 29.3, 11.7, 0.8]
# ['Farm and home management educators(1)', '25-9021', 0.7, 2.8, 7.1, 4, 26.7, 48.5, 10.2]
# ['Instructional coordinators(1)', '25-9031', 0.7, 2.8, 7.1, 4, 26.7, 48.5, 10.2]
# ['Teaching assistants, postsecondary(1)', '25-9044', 4.1, 25.1, 24.1, 14.5, 23.4, 7.4, 1.4]
# ['Teaching assistants, except postsecondary(1)', '25-9045', 4.1, 25.1, 24.1, 14.5, 23.4, 7.4, 1.4]
# ['Educational instruction and library workers, all other(1)', '25-9099', 0.7, 2.8, 7.1, 4, 26.7, 48.5, 10.2]
# ['Art directors(1)', '27-1011', 3.2, 12.2, 18.8, 8.9, 41.9, 13.5, 1.5]
# ['Craft artists(1)', '27-1012', 3.2, 12.2, 18.8, 8.9, 41.9, 13.5, 1.5]
# ['Fine artists, including painters, sculptors, and illustrators(1)', '27-1013', 3.2, 12.2, 18.8, 8.9, 41.9, 13.5, 1.5]
# ['Special effects artists and animators(1)', '27-1014', 3.2, 12.2, 18.8, 8.9, 41.9, 13.5, 1.5]
# ['Artists and related workers, all other(1)', '27-1019', 3.2, 12.2, 18.8, 8.9, 41.9, 13.5, 1.5]
# ['Commercial and industrial designers', '27-1021', 3.5, 5.3, 14.2, 2.9, 60.6, 11.3, 2.2]
# ['Fashion designers', '27-1022', 1.9, 5.2, 12.2, 11.7, 59, 8, 1.9]
# ['Floral designers', '27-1023', 10, 35.7, 23.7, 9.8, 17.4, 2.5, 0.9]
# ['Graphic designers', '27-1024', 1.2, 5.4, 13.9, 12.6, 59.6, 6.3, 1.2]
# ['Interior designers', '27-1025', 1.4, 6.2, 14.3, 12.1, 53.9, 9.5, 2.7]
# ['Merchandise displayers and window trimmers', '27-1026', 4.6, 30.7, 20.9, 9.4, 28.4, 5.2, 0.6]
# ['Set and exhibit designers(1)', '27-1027', 2, 8.1, 15.3, 13.8, 45.4, 13.3, 2]
# ['Designers, all other(1)', '27-1029', 2, 8.1, 15.3, 13.8, 45.4, 13.3, 2]
# ['Actors', '27-2011', 2.5, 12.5, 17.2, 6.6, 47.9, 12.5, 0.8]
# ['Producers and directors', '27-2012', 0.4, 5.5, 12, 5.7, 58.1, 16.4, 1.9]
# ['Athletes and sports competitors', '27-2021', 2.5, 11.7, 18.5, 7.8, 52.8, 6.5, 0.4]
# ['Coaches and scouts', '27-2022', 1.7, 9.8, 15.1, 6.9, 41.6, 22.2, 2.7]
# ['Umpires, referees, and other sports officials', '27-2023', 2.9, 7.2, 29.5, 8.7, 32.5, 14.4, 4.8]
# ['Dancers(1)', '27-2031', 5.1, 38, 21.7, 4.5, 25.3, 4.9, 0.5]
# ['Choreographers(1)', '27-2032', 5.1, 38, 21.7, 4.5, 25.3, 4.9, 0.5]
# ['Music directors and composers', '27-2041', 0.8, 7.4, 15.8, 5.4, 42.9, 22.4, 5.2]
# ['Musicians and singers', '27-2042', 3.7, 12.4, 21.7, 6.2, 31.4, 19.5, 5.2]
# ['Miscellaneous entertainers and performers, sports and related workers(1)', '27-2090', 2.3, 18.9, 31.9, 6.5, 32.9, 4.5, 3]
# ['Broadcast announcers and radio disc jockeys', '27-3011', 2.4, 13.9, 23.2, 10, 43.4, 5.6, 1.5]
# ['News analysts, reporters, and journalists', '27-3023', 0.5, 3.2, 8.3, 3.4, 57.1, 23.8, 3.7]
# ['Public relations specialists', '27-3031', 0.6, 2.9, 6.9, 5.1, 58.6, 22.1, 3.9]
# ['Editors', '27-3041', 0.9, 2.9, 9.2, 3.2, 55.2, 22.7, 6]
# ['Technical writers', '27-3042', 0.6, 5.2, 9.2, 7.8, 45.6, 23, 8.6]
# ['Writers and authors', '27-3043', 0.7, 3.4, 8.1, 3.4, 48.1, 27.8, 8.5]
# ['Interpreters and translators', '27-3091', 1.2, 8.2, 20.8, 14.7, 35.8, 15.9, 3.5]
# ['Court reporters and simultaneous captioners', '27-3092', 0.4, 13, 35.8, 38.8, 9.7, 1.6, 0.8]
# ['Media and communication workers, all other', '27-3099', 0.7, 7.1, 15.2, 5.5, 53.6, 17.8, 0.1]
# ['Audio and video technicians(1)', '27-4011', 1.5, 14.2, 23, 13.9, 40, 6, 1.4]
# ['Broadcast technicians(1)', '27-4012', 1.5, 14.2, 23, 13.9, 40, 6, 1.4]
# ['Sound engineering technicians(1)', '27-4014', 1.5, 14.2, 23, 13.9, 40, 6, 1.4]
# ['Photographers', '27-4021', 2.3, 12.3, 21.8, 12.2, 42.8, 7.6, 0.9]
# ['Camera operators, television, video, and film(1)', '27-4031', 1, 7.1, 19.5, 7.9, 55.2, 8.6, 0.7]
# ['Film and video editors(1)', '27-4032', 1, 7.1, 19.5, 7.9, 55.2, 8.6, 0.7]
# ['Lighting technicians and media and communication equipment workers, all other(1)', '27-4098', 1.5, 14.2, 23, 13.9, 40, 6, 1.4]
# ['Chiropractors', '29-1011', 0.4, 1.2, 1.1, 0, 4.5, 2.3, 90.5]
# ['Dentists, general(1)', '29-1021', 0, 0, 0, 0, 0, 2.3, 97.7]
# ['Oral and maxillofacial surgeons(1)', '29-1022', 0, 0, 0, 0, 0, 2.3, 97.7]
# ['Orthodontists(1)', '29-1023', 0, 0, 0, 0, 0, 2.3, 97.7]
# ['Prosthodontists(1)', '29-1024', 0, 0, 0, 0, 0, 2.3, 97.7]
# ['Dentists, all other specialists(1)', '29-1029', 0, 0, 0, 0, 0, 2.3, 97.7]
# ['Dietitians and nutritionists', '29-1031', 2.4, 8.6, 6.8, 3.1, 44.8, 28, 6.2]
# ['Optometrists', '29-1041', 0, 0, 0, 0, 0, 3.1, 96.9]
# ['Pharmacists', '29-1051', 0, 0, 1.9, 0.9, 26.9, 5.8, 64.5]
# ['Physician assistants', '29-1071', 0.6, 2.9, 3.1, 2.9, 15.9, 59.2, 15.4]
# ['Podiatrists', '29-1081', 0, 0, 0, 0, 0, 0.6, 99.4]
# ['Occupational therapists', '29-1122', 0.4, 0.8, 1.2, 4.7, 33.6, 53.2, 6]
# ['Physical therapists', '29-1123', 0.7, 1, 1.2, 2.4, 27.3, 21.3, 46]
# ['Radiation therapists', '29-1124', 0.4, 1.4, 7.9, 27.3, 50.2, 9.4, 3.4]
# ['Recreational therapists', '29-1125', 4.1, 20.4, 12.4, 3.6, 47.2, 9.5, 2.8]
# ['Respiratory therapists', '29-1126', 0.7, 3.3, 8.7, 56.3, 27, 2.8, 1.2]
# ['Speech-language pathologists', '29-1127', 0.7, 0.6, 0.7, 1.3, 10, 84.5, 2.3]
# ['Exercise physiologists(1)', '29-1128', 0.7, 3.8, 3.5, 4.4, 24.6, 55.8, 7.1]
# ['Therapists, all other(1)', '29-1129', 0.7, 3.8, 3.5, 4.4, 24.6, 55.8, 7.1]
# ['Veterinarians', '29-1131', 0, 0, 0, 0, 0, 3.1, 96.9]
# ['Registered nurses', '29-1141', 0.4, 0.9, 3.7, 29.6, 52.9, 10.4, 2.2]
# ['Nurse anesthetists', '29-1151', 1.2, 0.2, 0.4, 1.1, 11.3, 70.3, 15.5]
# ['Nurse midwives(1)', '29-1161', 0.1, 0.8, 0.3, 0.3, 6.3, 75.2, 17.1]
# ['Nurse practitioners(1)', '29-1171', 0.1, 0.8, 0.3, 0.3, 6.3, 75.2, 17.1]
# ['Audiologists', '29-1181', 0, 0.6, 0.9, 0.1, 10.4, 19.2, 68.8]
# ['Anesthesiologists(1)', '29-1211', 0, 0, 0, 0, 0, 0.1, 99.9]
# ['Family medicine physicians(1)', '29-1215', 0, 0, 0, 0, 0, 0.1, 99.9]
# ['General internal medicine physicians(1)', '29-1216', 0, 0, 0, 0, 0, 0.1, 99.9]
# ['Obstetricians and gynecologists(1)', '29-1218', 0, 0, 0, 0, 0, 0.1, 99.9]
# ['Pediatricians, general(1)', '29-1221', 0, 0, 0, 0, 0, 0.1, 99.9]
# ['Psychiatrists(1)', '29-1223', 0, 0, 0, 0, 0, 0.1, 99.9]
# ['Physicians, all other; and ophthalmologists, except pediatric(1)', '29-1228', 0, 0, 0, 0, 0, 0.1, 99.9]
# ['Surgeons, except ophthalmologists(1)', '29-1248', 0, 0, 0, 0, 0, 0, 100]
# ['Dental hygienists', '29-1292', 0.5, 2.1, 9, 51.1, 31.4, 3.2, 2.8]
# ['Acupuncturists and healthcare diagnosing or treating practitioners, all other(1)', '29-1298', 1.3, 2.3, 10.6, 2.9, 17.1, 39.2, 26.6]
# ['Clinical laboratory technologists and technicians', '29-2010', 1.2, 11.1, 21.9, 17.3, 38.4, 6.8, 3.3]
# ['Cardiovascular technologists and technicians', '29-2031', 1.4, 14.1, 28.9, 15.8, 26.9, 11.4, 1.4]
# ['Diagnostic medical sonographers', '29-2032', 0.8, 3.3, 12.4, 34, 38.4, 7.3, 3.8]
# ['Nuclear medicine technologists(1)', '29-2033', 3.6, 3.2, 7.4, 20.2, 51, 11.8, 2.8]
# ['Radiologic technologists and technicians', '29-2034', 1.3, 4.9, 14.5, 52.1, 23.1, 3.3, 0.7]
# ['Magnetic resonance imaging technologists', '29-2035', 1.5, 8.2, 11.8, 35.5, 34, 7, 2]
# ['Emergency medical technicians and paramedics(1)', '29-2040', 0.8, 10, 42.8, 23.8, 17.4, 2.7, 2.5]
# ['Dietetic technicians(1)', '29-2051', 7.3, 42.3, 26.9, 11.7, 10.1, 1.2, 0.5]
# ['Pharmacy technicians', '29-2052', 0.9, 26.2, 37.7, 16, 15.7, 2.6, 0.9]
# ['Psychiatric technicians', '29-2053', 1.3, 15.4, 26.2, 11.4, 36.4, 8.9, 0.4]
# ['Surgical technologists', '29-2055', 1.1, 12.6, 31.3, 41.3, 12.2, 0.9, 0.7]
# ['Veterinary technologists and technicians', '29-2056', 1.5, 15.7, 23.7, 33.2, 22.5, 2.1, 1.4]
# ['Ophthalmic medical technicians(1)', '29-2057', 7.3, 42.3, 26.9, 11.7, 10.1, 1.2, 0.5]
# ['Licensed practical and licensed vocational nurses', '29-2061', 1.2, 20.7, 55.7, 17.6, 4, 0.6, 0.2]
# ['Opticians, dispensing', '29-2081', 2.5, 25.2, 33.5, 16.6, 20.9, 1, 0.4]
# ['Orthotists and prosthetists(1)', '29-2091', 2.8, 18.4, 34.9, 16.3, 19.1, 5.7, 2.9]
# ['Hearing aid specialists(1)', '29-2092', 2.8, 18.4, 34.9, 16.3, 19.1, 5.7, 2.9]
# ['Medical dosimetrists, medical records specialists, and health technologists and technicians, all other(1)', '29-2098', 1.6, 15.1, 27.3, 19.5, 22.7, 11.7, 2]
# ['Athletic trainers(1)', '29-9091', 0.6, 4, 12.3, 7.9, 33.1, 38.5, 3.7]
# ['Genetic counselors(1)', '29-9092', 0.6, 4, 12.3, 7.9, 33.1, 38.5, 3.7]
# ['Health information technologists, medical registrars, surgical assistants, and healthcare practitioners and technical workers, all other(1)', '29-9098', 0.6, 4, 12.3, 7.9, 33.1, 38.5, 3.7]
# ['Home health and personal care aides(1)', '31-1120', 16.4, 35.9, 25.7, 9.2, 9.8, 2.3, 0.6]
# ['Nursing assistants', '31-1131', 8.7, 37.4, 33.3, 11.4, 7.7, 0.9, 0.7]
# ['Orderlies(1)', '31-1132', 4.5, 29.6, 35, 13, 14.8, 2.5, 0.6]
# ['Psychiatric aides(1)', '31-1133', 4.5, 29.6, 35, 13, 14.8, 2.5, 0.6]
# ['Occupational therapy assistants(1)', '31-2011', 1.4, 12.9, 13.5, 49.1, 18.5, 4, 0.5]
# ['Occupational therapy aides(1)', '31-2012', 1.4, 12.9, 13.5, 49.1, 18.5, 4, 0.5]
# ['Physical therapist assistants(1)', '31-2021', 1.5, 5.2, 8.2, 52, 29, 2.5, 1.7]
# ['Physical therapist aides(1)', '31-2022', 1.5, 5.2, 8.2, 52, 29, 2.5, 1.7]
# ['Massage therapists', '31-9011', 2.8, 20.4, 32, 18.1, 20.4, 3.7, 2.6]
# ['Dental assistants', '31-9091', 3.5, 27.8, 36.5, 19.4, 10.2, 1.1, 1.5]
# ['Medical assistants', '31-9092', 2, 20.3, 39, 24.4, 10.9, 2.3, 1.2]
# ['Medical equipment preparers(1)', '31-9093', 6.2, 29.3, 29.8, 13.4, 16.1, 3.7, 1.4]
# ['Medical transcriptionists', '31-9094', 0.8, 18.8, 31.7, 16.8, 22.9, 3.4, 5.5]
# ['Pharmacy aides', '31-9095', 4.5, 31, 23.5, 16, 16.4, 1.6, 7]
# ['Veterinary assistants and laboratory animal caretakers', '31-9096', 4, 22.3, 30.4, 13.6, 25.8, 3.2, 0.7]
# ['Phlebotomists', '31-9097', 2.1, 25.1, 41.5, 18.2, 11, 1.7, 0.3]
# ['Healthcare support workers, all other(1)', '31-9099', 6.2, 29.3, 29.8, 13.4, 16.1, 3.7, 1.4]
# ['First-line supervisors of correctional officers', '33-1011', 2.1, 25.4, 28.8, 13.6, 22.8, 7, 0.4]
# ['First-line supervisors of police and detectives', '33-1012', 0.5, 13.6, 25.7, 15.3, 31.1, 12.1, 1.8]
# ['First-line supervisors of firefighting and prevention workers', '33-1021', 0.8, 10.9, 34, 21.2, 25, 7.3, 0.7]
# ['Miscellaneous first-line supervisors, protective service workers', '33-1090', 1.8, 23.2, 27.3, 10.5, 26.7, 8.9, 1.6]
# ['Firefighters', '33-2011', 0.8, 13.4, 37.3, 22.1, 22.7, 2.8, 0.8]
# ['Fire inspectors and investigators(1)', '33-2021', 4.9, 20.7, 27.5, 16.6, 22, 5.8, 2.5]
# ['Forest fire inspectors and prevention specialists(1)', '33-2022', 4.9, 20.7, 27.5, 16.6, 22, 5.8, 2.5]
# ['Bailiffs', '33-3011', 1, 23.4, 22, 16.7, 27.1, 7.7, 2.1]
# ['Correctional officers and jailers', '33-3012', 1, 29.7, 35.1, 14.2, 16.9, 2.7, 0.5]
# ['Detectives and criminal investigators', '33-3021', 0.5, 9.7, 20.9, 11.1, 41.8, 13.8, 2.3]
# ['Fish and game wardens(1)', '33-3031', 0.3, 20, 22.7, 16.4, 34.1, 5.7, 0.7]
# ['Parking enforcement workers(1)', '33-3041', 0.3, 20, 22.7, 16.4, 34.1, 5.7, 0.7]
# ["Police and sheriff's patrol officers(1)", '33-3051', 0.7, 12.3, 29.9, 16.5, 33, 6.6, 0.9]
# ['Transit and railroad police(1)', '33-3052', 0.7, 12.3, 29.9, 16.5, 33, 6.6, 0.9]
# ['Animal control workers', '33-9011', 3.2, 38.2, 34.6, 11.5, 10.5, 1.5, 0.6]
# ['Private detectives and investigators', '33-9021', 0.6, 9.4, 20.6, 12.1, 42, 11.8, 3.4]
# ['Gambling surveillance officers and gambling investigators(1)', '33-9031', 5.5, 35.6, 31.1, 10.8, 13.4, 3.2, 0.5]
# ['Security guards(1)', '33-9032', 5.5, 35.6, 31.1, 10.8, 13.4, 3.2, 0.5]
# ['Crossing guards and flaggers', '33-9091', 17.3, 43.9, 23.9, 5.7, 8.2, 0.8, 0.2]
# ['Lifeguards, ski patrol, and other recreational protective service workers(1)', '33-9092', 1.8, 20.3, 27.3, 8.5, 31.6, 9.3, 1.3]
# ['Transportation security screeners', '33-9093', 2.8, 23.9, 35.8, 10.9, 21.4, 4.9, 0.3]
# ['School bus monitors and protective service workers, all other(1)', '33-9098', 6.9, 32.7, 27.4, 9.4, 17.6, 5.3, 0.7]
# ['Chefs and head cooks', '35-1011', 16.2, 31.8, 19.6, 16.2, 13.7, 1.8, 0.6]
# ['First-line supervisors of food preparation and serving workers', '35-1012', 11.2, 37.2, 27.6, 9.1, 13.1, 1.5, 0.3]
# ['Cooks, fast food(1)', '35-2011', 27, 42.6, 18.2, 6.1, 5.4, 0.5, 0.2]
# ['Cooks, institution and cafeteria(1)', '35-2012', 27, 42.6, 18.2, 6.1, 5.4, 0.5, 0.2]
# ['Cooks, private household(1)', '35-2013', 27, 42.6, 18.2, 6.1, 5.4, 0.5, 0.2]
# ['Cooks, restaurant(1)', '35-2014', 27, 42.6, 18.2, 6.1, 5.4, 0.5, 0.2]
# ['Cooks, short order(1)', '35-2015', 27, 42.6, 18.2, 6.1, 5.4, 0.5, 0.2]
# ['Cooks, all other(1)', '35-2019', 27, 42.6, 18.2, 6.1, 5.4, 0.5, 0.2]
# ['Food preparation workers', '35-2021', 24, 42.4, 19.5, 5.6, 7.1, 1.1, 0.3]
# ['Bartenders', '35-3011', 5.4, 27.9, 32.7, 11.3, 19.9, 2.3, 0.5]
# ['Fast food and counter workers', '35-3023', 13.9, 35.7, 27.3, 7.9, 13.2, 1.5, 0.5]
# ['Waiters and waitresses', '35-3031', 13.4, 33.5, 27.5, 9.3, 14, 1.8, 0.4]
# ['Food servers, nonrestaurant', '35-3041', 14.1, 42.7, 24.5, 8.3, 9, 1.5, 0]
# ['Dining room and cafeteria attendants and bartender helpers', '35-9011', 22.5, 42.1, 20.1, 7.2, 6.9, 1, 0.2]
# ['Dishwashers', '35-9021', 36.2, 43.3, 11.5, 3.6, 4.7, 0.6, 0.2]
# ['Hosts and hostesses, restaurant, lounge, and coffee shop', '35-9031', 11.6, 33, 27.1, 10.6, 14.1, 3.1, 0.6]
# ['Food preparation and serving related workers, all other', '35-9099', 18.6, 42.3, 25.4, 7.4, 4, 2.3, 0]
# ['First-line supervisors of housekeeping and janitorial workers', '37-1011', 13, 41.5, 23.3, 7.7, 11.7, 2.2, 0.6]
# ['First-line supervisors of landscaping, lawn service, and groundskeeping workers', '37-1012', 21.7, 31.9, 22, 9, 14.1, 1.3, 0]
# ['Janitors and cleaners, except maids and housekeeping cleaners(1)', '37-2011', 23.3, 45.3, 18.2, 6.4, 5.5, 1, 0.2]
# ['Maids and housekeeping cleaners', '37-2012', 34.9, 41.4, 13.6, 4.4, 4.6, 0.7, 0.4]
# ['Building cleaning workers, all other(1)', '37-2019', 23.3, 45.3, 18.2, 6.4, 5.5, 1, 0.2]
# ['Pest control workers', '37-2021', 7, 48.7, 27.8, 8.1, 7.5, 0.7, 0.2]
# ['Landscaping and groundskeeping workers', '37-3011', 35.1, 35.8, 16.3, 5, 6.3, 1.3, 0.3]
# ['Pesticide handlers, sprayers, and applicators, vegetation(1)', '37-3012', 21.2, 30.9, 22.2, 10.6, 15, 0, 0]
# ['Tree trimmers and pruners', '37-3013', 30.2, 40.1, 12.5, 5.6, 9.1, 1.8, 0.7]
# ['Grounds maintenance workers, all other(1)', '37-3019', 21.2, 30.9, 22.2, 10.6, 15, 0, 0]
# ['First-line supervisors of gambling services workers(1)', '39-1013', 5.8, 30.9, 28.5, 10, 20.3, 3.5, 1]
# ['First-line supervisors of personal service and entertainment and recreation workers, except gambling services(1)', '39-1098', 6.4, 35, 28.8, 10.4, 16.4, 2.5, 0.4]
# ['Animal trainers', '39-2011', 6.9, 23.4, 22.3, 9.7, 31.1, 5, 1.6]
# ['Animal caretakers', '39-2021', 7, 29.4, 30, 10.4, 20.1, 2.4, 0.7]
# ['Gambling dealers(1)', '39-3011', 9.9, 33.5, 27.1, 10.8, 16.1, 1.8, 0.8]
# ['Gambling and sports book writers and runners(1)', '39-3012', 9.9, 33.5, 27.1, 10.8, 16.1, 1.8, 0.8]
# ['Gambling service workers, all other(1)', '39-3019', 9.9, 33.5, 27.1, 10.8, 16.1, 1.8, 0.8]
# ['Motion picture projectionists(1)', '39-3021', 7, 29.2, 26.8, 9, 22.2, 4.7, 1.1]
# ['Ushers, lobby attendants, and ticket takers', '39-3031', 8.5, 31.5, 21, 10.7, 19.7, 7.4, 1.2]
# ['Amusement and recreation attendants(1)', '39-3091', 7, 29.2, 26.8, 9, 22.2, 4.7, 1.1]
# ['Costume attendants(1)', '39-3092', 7, 29.2, 26.8, 9, 22.2, 4.7, 1.1]
# ['Locker room, coatroom, and dressing room attendants(1)', '39-3093', 7, 29.2, 26.8, 9, 22.2, 4.7, 1.1]
# ['Entertainment attendants and related workers, all other(1)', '39-3099', 7, 29.2, 26.8, 9, 22.2, 4.7, 1.1]
# ['Embalmers(1)', '39-4011', 3.6, 27.7, 23.7, 16.9, 22.7, 4.5, 0.9]
# ['Funeral attendants(1)', '39-4021', 3.6, 27.7, 23.7, 16.9, 22.7, 4.5, 0.9]
# ['Morticians, undertakers, and funeral arrangers', '39-4031', 3.3, 7.4, 16.5, 40.2, 26.1, 3.2, 3.3]
# ['Barbers', '39-5011', 11.2, 46.4, 26.6, 8.3, 6.4, 1.2, 0.1]
# ['Hairdressers, hairstylists, and cosmetologists', '39-5012', 5.8, 43.8, 31.8, 11.2, 6, 1.1, 0.3]
# ['Makeup artists, theatrical and performance(1)', '39-5091', 3.4, 25.7, 38.9, 11.2, 17.5, 2.8, 0.5]
# ['Manicurists and pedicurists', '39-5092', 27.5, 41.2, 17, 6.5, 6.5, 0.9, 0.4]
# ['Shampooers(1)', '39-5093', 3.4, 25.7, 38.9, 11.2, 17.5, 2.8, 0.5]
# ['Skincare specialists', '39-5094', 2.4, 25.4, 35.4, 16.4, 17.3, 2.6, 0.5]
# ['Baggage porters and bellhops(1)', '39-6011', 8.9, 30.1, 28.9, 10.3, 18.7, 2.7, 0.5]
# ['Concierges(1)', '39-6012', 8.9, 30.1, 28.9, 10.3, 18.7, 2.7, 0.5]
# ['Tour and travel guides', '39-7010', 3.1, 21.5, 23.1, 6.6, 35.8, 8.7, 1.1]
# ['Childcare workers', '39-9011', 12.3, 32.3, 24.1, 11, 16.5, 3.1, 0.6]
# ['Exercise trainers and group fitness instructors', '39-9031', 2.2, 9.3, 19, 9.6, 45, 12.8, 2.1]
# ['Recreation workers', '39-9032', 4.3, 24.1, 24.5, 11.2, 28.4, 6.5, 1]
# ['Residential advisors', '39-9041', 4.4, 12.5, 27.8, 12.7, 30.9, 10.8, 0.9]
# ['Crematory operators and personal care and service workers, all other(1)', '39-9098', 9.7, 26.1, 28.5, 9.6, 20.6, 4.4, 1.1]
# ['First-line supervisors of retail sales workers', '41-1011', 5.7, 29.3, 28.7, 10.1, 21.4, 4.1, 0.8]
# ['First-line supervisors of non-retail sales workers', '41-1012', 5.3, 21.6, 22.9, 10.1, 30.7, 8.3, 1.1]
# ['Cashiers(1)', '41-2011', 14.6, 41, 24.7, 7.1, 10.4, 1.8, 0.3]
# ['Gambling change persons and booth cashiers(1)', '41-2012', 14.6, 41, 24.7, 7.1, 10.4, 1.8, 0.3]
# ['Counter and rental clerks', '41-2021', 6.6, 37, 26.9, 8.6, 18, 2.8, 0.1]
# ['Parts salespersons', '41-2022', 8.8, 47.8, 27, 9.1, 6.3, 0.9, 0.1]
# ['Retail salespersons', '41-2031', 6.3, 29.7, 28, 10, 21.5, 3.8, 0.7]
# ['Advertising sales agents', '41-3011', 1.4, 9.4, 19.8, 7, 53, 8.3, 1.1]
# ['Insurance sales agents', '41-3021', 1.1, 14.4, 25.6, 10.9, 39.9, 6.8, 1.2]
# ['Securities, commodities, and financial services sales agents', '41-3031', 0.6, 7.9, 14.3, 5.8, 49.4, 18.7, 3.3]
# ['Travel agents', '41-3041', 3.7, 19.2, 23.7, 12.2, 33.6, 6.6, 1]
# ['Sales representatives of services, except advertising, insurance, financial services, and travel', '41-3091', 1.8, 14.6, 21.8, 7.4, 44.1, 9.5, 0.8]
# ['Sales representatives, wholesale and manufacturing, technical and scientific products(1)', '41-4011', 2.8, 16.7, 22.9, 9.2, 40.4, 7, 0.9]
# ['Sales representatives, wholesale and manufacturing, except technical and scientific products(1)', '41-4012', 2.8, 16.7, 22.9, 9.2, 40.4, 7, 0.9]
# ['Demonstrators and product promoters(1)', '41-9011', 8, 27.1, 27.3, 12.2, 20.3, 4, 1.1]
# ['Models(1)', '41-9012', 8, 27.1, 27.3, 12.2, 20.3, 4, 1.1]
# ['Real estate brokers(1)', '41-9021', 1.5, 12.5, 25.3, 9.7, 38.4, 10.4, 2.1]
# ['Real estate sales agents(1)', '41-9022', 1.5, 12.5, 25.3, 9.7, 38.4, 10.4, 2.1]
# ['Sales engineers', '41-9031', 0.4, 4.6, 10.4, 5.8, 59.8, 17.9, 1.1]
# ['Telemarketers', '41-9041', 7.4, 37, 24.4, 10.7, 18.7, 1.7, 0]
# ['Door-to-door sales workers, news and street vendors, and related workers', '41-9091', 14.7, 31.6, 20.9, 8.5, 18.9, 4.9, 0.6]
# ['Sales and related workers, all other', '41-9099', 4, 18.5, 20.1, 8, 38.7, 9.5, 1.4]
# ['First-line supervisors of office and administrative support workers', '43-1011', 2.7, 21.5, 28.3, 13.1, 26.7, 6.6, 1.1]
# ['Switchboard operators, including answering service', '43-2011', 2.6, 29.8, 37.5, 11.5, 17.1, 1.5, 0]
# ['Telephone operators', '43-2021', 2.4, 38, 30.9, 8.5, 17.1, 3.2, 0]
# ['Communications equipment operators, all other', '43-2099', 0, 4.9, 34.8, 13.9, 41.9, 3.9, 0.7]
# ['Bill and account collectors', '43-3011', 3.1, 28.3, 34.6, 15.5, 15.8, 2, 0.7]
# ['Billing and posting clerks', '43-3021', 2.2, 27.7, 32.5, 16.6, 16.7, 3.5, 0.8]
# ['Bookkeeping, accounting, and auditing clerks', '43-3031', 3.4, 26.4, 36.9, 13.2, 16.5, 3.2, 0.4]
# ['Gambling cage workers(1)', '43-3041', 2, 15.1, 26.1, 9.3, 35.1, 11.8, 0.6]
# ['Payroll and timekeeping clerks', '43-3051', 2.8, 24.1, 34.9, 15.1, 19.3, 3.2, 0.6]
# ['Procurement clerks', '43-3061', 1.5, 17.7, 27.3, 11.2, 33.9, 7.2, 1.2]
# ['Tellers', '43-3071', 0.7, 33.5, 31.3, 14.1, 18.1, 1.9, 0.3]
# ['Financial clerks, all other(1)', '43-3099', 2, 15.1, 26.1, 9.3, 35.1, 11.8, 0.6]
# ['Brokerage clerks(1)', '43-4011', 2.1, 21.6, 30, 14.1, 23.5, 7.4, 1.3]
# ['Correspondence clerks(1)', '43-4021', 7, 33.6, 27.6, 10.5, 18.2, 2.5, 0.5]
# ['Court, municipal, and license clerks', '43-4031', 0.7, 25.7, 31.7, 12.7, 23.5, 4, 1.6]
# ['Credit authorizers, checkers, and clerks', '43-4041', 0.5, 24.1, 31.6, 9.7, 27.6, 6.1, 0.4]
# ['Customer service representatives', '43-4051', 4.1, 26.6, 30.2, 11.7, 22.6, 4.2, 0.6]
# ['Eligibility interviewers, government programs', '43-4061', 1.6, 10.7, 24.8, 15.4, 36.9, 9, 1.5]
# ['File clerks', '43-4071', 4.2, 27, 29.4, 14.8, 18.7, 4.5, 1.3]
# ['Hotel, motel, and resort desk clerks', '43-4081', 5.6, 31.6, 32.3, 11.2, 15.7, 2.7, 0.9]
# ['Interviewers, except eligibility and loan', '43-4111', 1.9, 24.7, 31.8, 11.9, 22.2, 6.4, 1.1]
# ['Library assistants, clerical', '43-4121', 1.8, 15.4, 23.7, 13.3, 34.4, 10.2, 1.2]
# ['Loan interviewers and clerks', '43-4131', 1.5, 24.5, 30.7, 14.9, 24.4, 3.6, 0.3]
# ['New accounts clerks', '43-4141', 0.8, 22.3, 35.3, 13.5, 27.7, 0.5, 0]
# ['Order clerks(1)', '43-4151', 7, 33.6, 27.6, 10.5, 18.2, 2.5, 0.5]
# ['Human resources assistants, except payroll and timekeeping', '43-4161', 1.6, 20, 24.9, 10.6, 33.2, 9.4, 0.4]
# ['Receptionists and information clerks', '43-4171', 3.3, 33.8, 32.5, 13.3, 14.3, 2.3, 0.5]
# ['Reservation and transportation ticket agents and travel clerks', '43-4181', 2.8, 24.2, 30.1, 12.3, 26.2, 3.6, 0.8]
# ['Information and record clerks, all other(1)', '43-4199', 2.1, 21.6, 30, 14.1, 23.5, 7.4, 1.3]
# ['Cargo and freight agents', '43-5011', 2.7, 29.5, 30.1, 10.6, 22.9, 1.7, 2.4]
# ['Couriers and messengers', '43-5021', 7.7, 36.4, 30.9, 10.2, 12.2, 2, 0.6]
# ['Public safety telecommunicators', '43-5031', 0.9, 23.9, 39.8, 14.2, 17.9, 2.9, 0.3]
# ['Dispatchers, except police, fire, and ambulance', '43-5032', 7.1, 34, 31.8, 10.7, 14.1, 1.7, 0.5]
# ['Meter readers, utilities', '43-5041', 2.5, 51.3, 33.7, 7.9, 4, 0.5, 0]
# ['Postal service clerks', '43-5051', 1.4, 34.4, 33.6, 12.8, 14.5, 2.6, 0.7]
# ['Postal service mail carriers', '43-5052', 2.4, 34.1, 34.5, 12.6, 13.9, 2, 0.6]
# ['Postal service mail sorters, processors, and processing machine operators', '43-5053', 6.5, 28.3, 34.4, 11.9, 15.3, 3.1, 0.6]
# ['Production, planning, and expediting clerks', '43-5061', 2.5, 23.3, 27.9, 11.9, 26.4, 7.2, 0.7]
# ['Shipping, receiving, and inventory clerks', '43-5071', 11.7, 44, 25.8, 8, 9.2, 1.1, 0.2]
# ['Weighers, measurers, checkers, and samplers, recordkeeping', '43-5111', 11.7, 35.2, 25.4, 10.5, 14.1, 2.8, 0.4]
# ['Executive secretaries and executive administrative assistants', '43-6011', 0.9, 15.8, 26.7, 14.3, 34.2, 7.2, 0.9]
# ['Legal secretaries and administrative assistants', '43-6012', 2.2, 22.7, 34.5, 18.7, 18, 3.1, 0.8]
# ['Medical secretaries and administrative assistants', '43-6013', 4.5, 21.9, 36.2, 17.4, 17.1, 1.9, 1.1]
# ['Secretaries and administrative assistants, except legal, medical, and executive', '43-6014', 2.5, 25.8, 31.1, 14.8, 21.2, 4.1, 0.6]
# ['Data entry keyers', '43-9021', 4, 26.6, 31.7, 14.3, 18.9, 4, 0.6]
# ['Word processors and typists', '43-9022', 2.2, 26.9, 29.9, 18.5, 18.1, 3.4, 1]
# ['Desktop publishers(1)', '43-9031', 2.2, 18.6, 28.2, 12.5, 28.5, 9, 1]
# ['Insurance claims and policy processing clerks', '43-9041', 2, 25.7, 31.8, 13.4, 21.7, 4.3, 1.2]
# ['Mail clerks and mail machine operators, except postal service', '43-9051', 8.1, 41.8, 22.2, 11.9, 12.6, 2.7, 0.8]
# ['Office clerks, general', '43-9061', 3.4, 29.6, 32.2, 13, 17.8, 3.5, 0.7]
# ['Office machine operators, except computer', '43-9071', 9.2, 36.2, 29, 10.4, 12, 3.3, 0]
# ['Proofreaders and copy markers', '43-9081', 0.3, 21.8, 15.5, 3.3, 35.5, 21.9, 1.7]
# ['Statistical assistants', '43-9111', 1, 12.7, 26.7, 9, 35.9, 13.5, 1.3]
# ['Office and administrative support workers, all other(1)', '43-9199', 2.2, 18.6, 28.2, 12.5, 28.5, 9, 1]
# ['First-line supervisors of farming, fishing, and forestry workers', '45-1011', 37.6, 30, 16.6, 5.3, 8.3, 1.1, 1.1]
# ['Agricultural inspectors', '45-2011', 3.2, 20.5, 29.5, 11.6, 30.9, 4.2, 0]
# ['Animal breeders(1)', '45-2021', 50.2, 27.7, 10.8, 4.1, 6.1, 0.8, 0.2]
# ['Graders and sorters, agricultural products', '45-2041', 50.7, 31.7, 9.9, 1.4, 4.5, 0.4, 1.5]
# ['Agricultural equipment operators(1)', '45-2091', 50.2, 27.7, 10.8, 4.1, 6.1, 0.8, 0.2]
# ['Farmworkers and laborers, crop, nursery, and greenhouse(1)', '45-2092', 50.2, 27.7, 10.8, 4.1, 6.1, 0.8, 0.2]
# ['Farmworkers, farm, ranch, and aquacultural animals(1)', '45-2093', 50.2, 27.7, 10.8, 4.1, 6.1, 0.8, 0.2]
# ['Agricultural workers, all other(1)', '45-2099', 50.2, 27.7, 10.8, 4.1, 6.1, 0.8, 0.2]
# ['Fishing and hunting workers', '45-3031', 24.7, 40.9, 19.3, 3.4, 9.9, 1.5, 0.3]
# ['Forest and conservation workers', '45-4011', 26, 28.9, 21.5, 2.9, 14.8, 4.7, 1.2]
# ['Fallers(1)', '45-4021', 32.3, 42.9, 12.9, 6.2, 5.1, 0.5, 0.1]
# ['Logging equipment operators(1)', '45-4022', 32.3, 42.9, 12.9, 6.2, 5.1, 0.5, 0.1]
# ['Log graders and scalers(1)', '45-4023', 32.3, 42.9, 12.9, 6.2, 5.1, 0.5, 0.1]
# ['Logging workers, all other(1)', '45-4029', 32.3, 42.9, 12.9, 6.2, 5.1, 0.5, 0.1]
# ['First-line supervisors of construction trades and extraction workers', '47-1011', 16.6, 44.1, 22.5, 6.7, 8.5, 1.3, 0.3]
# ['Boilermakers', '47-2011', 4.5, 58.3, 29.1, 4.9, 3.2, 0, 0]
# ['Brickmasons and blockmasons(1)', '47-2021', 31.4, 46.2, 15.6, 3.6, 2.9, 0.2, 0.1]
# ['Stonemasons(1)', '47-2022', 31.4, 46.2, 15.6, 3.6, 2.9, 0.2, 0.1]
# ['Carpenters', '47-2031', 25.2, 42.2, 19.3, 5.8, 6.4, 0.8, 0.3]
# ['Carpet installers(1)', '47-2041', 31.4, 42, 16.6, 4.7, 4.2, 0.8, 0.3]
# ['Floor layers, except carpet, wood, and hard tiles(1)', '47-2042', 31.4, 42, 16.6, 4.7, 4.2, 0.8, 0.3]
# ['Floor sanders and finishers(1)', '47-2043', 31.4, 42, 16.6, 4.7, 4.2, 0.8, 0.3]
# ['Tile and stone setters(1)', '47-2044', 31.4, 42, 16.6, 4.7, 4.2, 0.8, 0.3]
# ['Cement masons and concrete finishers(1)', '47-2051', 40.5, 40, 15.6, 1.8, 2.1, 0.1, 0]
# ['Terrazzo workers and finishers(1)', '47-2053', 40.5, 40, 15.6, 1.8, 2.1, 0.1, 0]
# ['Construction laborers', '47-2061', 32.5, 39.7, 16.2, 4.6, 5.6, 1, 0.3]
# ['Paving, surfacing, and tamping equipment operators(1)', '47-2071', 20.1, 52.2, 18.2, 6.3, 2.6, 0.6, 0]
# ['Pile driver operators(1)', '47-2072', 20.1, 52.2, 18.2, 6.3, 2.6, 0.6, 0]
# ...
# ['Commercial divers(1)', '49-9092', 13.2, 39.1, 27.5, 9.3, 9.5, 1.1, 0.3]
# ['Locksmiths and safe repairers', '49-9094', 3.2, 47.3, 26.5, 8.6, 13.2, 1.2, 0]
# ['Manufactured building and mobile home installers(1)', '49-9095', 13.2, 39.1, 27.5, 9.3, 9.5, 1.1, 0.3]
# ['Riggers', '49-9096', 8.4, 54, 21.3, 5.4, 10.8, 0, 0]
# ['Signal and track switch repairers(1)', '49-9097', 13.2, 39.1, 27.5, 9.3, 9.5, 1.1, 0.3]
# ['Helpers--installation, maintenance, and repair workers', '49-9098', 32.8, 46.2, 14.5, 2.2, 3.8, 0.5, 0]
# ['Installation, maintenance, and repair workers, all other(1)', '49-9099', 13.2, 39.1, 27.5, 9.3, 9.5, 1.1, 0.3]
# ['First-line supervisors of production and operating workers', '51-1011', 10.3, 39.2, 26.3, 9, 12.2, 2.6, 0.5]
# ['Aircraft structure, surfaces, rigging, and systems assemblers(1)', '51-2011', 16.1, 47.1, 21.9, 7.8, 6, 0.8, 0.2]
# ['Coil winders, tapers, and finishers(1)', '51-2021', 17.7, 44.4, 22.8, 6.7, 6.7, 1.4, 0.2]
# ['Electrical, electronic, and electromechanical assemblers, except coil winders, tapers, and finishers(1)', '51-2028', 17.7, 44.4, 22.8, 6.7, 6.7, 1.4, 0.2]
# ['Engine and other machine assemblers', '51-2031', 14.8, 43, 29.8, 5.7, 6.7, 0, 0]
# ['Structural metal fabricators and fitters', '51-2041', 15.3, 49.2, 20.5, 8.4, 5.6, 1, 0]
# ['Fiberglass laminators and fabricators(1)', '51-2051', 16.1, 47.1, 21.9, 7.8, 6, 0.8, 0.2]
# ['Timing device assemblers and adjusters(1)', '51-2061', 16.1, 47.1, 21.9, 7.8, 6, 0.8, 0.2]
# ['Miscellaneous assemblers and fabricators(1)', '51-2090', 16.1, 47.1, 21.9, 7.8, 6, 0.8, 0.2]
# ['Bakers', '51-3011', 19.4, 40.1, 20.1, 7.9, 10.3, 1.4, 0.8]
# ['Butchers and meat cutters(1)', '51-3021', 29.1, 43.8, 18.3, 4.1, 4, 0.6, 0.1]
# ['Meat, poultry, and fish cutters and trimmers(1)', '51-3022', 29.1, 43.8, 18.3, 4.1, 4, 0.6, 0.1]
# ['Slaughterers and meat packers(1)', '51-3023', 29.1, 43.8, 18.3, 4.1, 4, 0.6, 0.1]
# ['Food and tobacco roasting, baking, and drying machine operators and tenders', '51-3091', 18.5, 46.4, 17.6, 1.3, 15, 1.2, 0]
# ['Food batchmakers', '51-3092', 19.1, 39.1, 25.8, 6.7, 6.7, 1.6, 0.9]
# ['Food cooking machine operators and tenders', '51-3093', 23.7, 44.7, 17.2, 3.3, 9.7, 1.5, 0]
# ['Food processing workers, all other', '51-3099', 26.7, 42.6, 20.8, 5.5, 3.7, 0.6, 0.1]
# ['Extruding and drawing machine setters, operators, and tenders, metal and plastic(1)', '51-4021', 12.7, 52.4, 20.5, 9.9, 1.9, 2.6, 0]
# ['Forging machine setters, operators, and tenders, metal and plastic(1)', '51-4022', 12.7, 52.4, 20.5, 9.9, 1.9, 2.6, 0]
# ['Rolling machine setters, operators, and tenders, metal and plastic(1)', '51-4023', 12.7, 52.4, 20.5, 9.9, 1.9, 2.6, 0]
# ['Cutting, punching, and press machine setters, operators, and tenders, metal and plastic', '51-4031', 16.9, 52.1, 20.4, 7.4, 3.1, 0.1, 0.1]
# ['Drilling and boring machine tool setters, operators, and tenders, metal and plastic(1)', '51-4032', 19.2, 47.1, 24.9, 4.5, 0.9, 3.3, 0]
# ['Grinding, lapping, polishing, and buffing machine tool setters, operators, and tenders, metal and plastic', '51-4033', 20.3, 50.4, 18.9, 6.3, 4, 0.2, 0.1]
# ['Lathe and turning machine tool setters, operators, and tenders, metal and plastic(1)', '51-4034', 19.2, 47.1, 24.9, 4.5, 0.9, 3.3, 0]
# ['Milling and planing machine setters, operators, and tenders, metal and plastic(1)', '51-4035', 19.2, 47.1, 24.9, 4.5, 0.9, 3.3, 0]
# ['Machinists', '51-4041', 9.6, 44.2, 29.1, 12.1, 4.4, 0.4, 0.2]
# ['Metal-refining furnace operators and tenders(1)', '51-4051', 13.6, 46.1, 24.1, 5.8, 10, 0.4, 0]
# ['Pourers and casters, metal(1)', '51-4052', 13.6, 46.1, 24.1, 5.8, 10, 0.4, 0]
# ['Model makers, metal and plastic(1)', '51-4061', 13.4, 42.5, 26.6, 10.4, 5.4, 1.6, 0.2]
# ['Patternmakers, metal and plastic(1)', '51-4062', 13.4, 42.5, 26.6, 10.4, 5.4, 1.6, 0.2]
# ['Foundry mold and coremakers(1)', '51-4071', 13.4, 42.5, 26.6, 10.4, 5.4, 1.6, 0.2]
# ['Molding, coremaking, and casting machine setters, operators, and tenders, metal and plastic(1)', '51-4072', 13.4, 42.5, 26.6, 10.4, 5.4, 1.6, 0.2]
# ['Multiple machine tool setters, operators, and tenders, metal and plastic(1)', '51-4081', 17.8, 48.2, 21.9, 6.4, 4.9, 0.8, 0.1]
# ['Tool and die makers', '51-4111', 4.2, 42.3, 34.2, 14.2, 3.2, 1, 0.8]
# ['Welders, cutters, solderers, and brazers(1)', '51-4121', 18.6, 46, 23.3, 8.9, 2.4, 0.5, 0.2]
# ['Welding, soldering, and brazing machine setters, operators, and tenders(1)', '51-4122', 18.6, 46, 23.3, 8.9, 2.4, 0.5, 0.2]
# ['Heat treating equipment setters, operators, and tenders, metal and plastic(1)', '51-4191', 17.8, 48.2, 21.9, 6.4, 4.9, 0.8, 0.1]
# ['Layout workers, metal and plastic(1)', '51-4192', 17.8, 48.2, 21.9, 6.4, 4.9, 0.8, 0.1]
# ['Plating machine setters, operators, and tenders, metal and plastic(1)', '51-4193', 17.8, 48.2, 21.9, 6.4, 4.9, 0.8, 0.1]
# ['Tool grinders, filers, and sharpeners(1)', '51-4194', 17.8, 48.2, 21.9, 6.4, 4.9, 0.8, 0.1]
# ['Metal workers and plastic workers, all other(1)', '51-4199', 17.8, 48.2, 21.9, 6.4, 4.9, 0.8, 0.1]
# ['Prepress technicians and workers', '51-5111', 4.4, 38, 25.9, 12.3, 15.4, 2.9, 1.1]
# ['Printing press operators', '51-5112', 12.8, 45.4, 23.5, 9.4, 7.9, 0.5, 0.5]
# ['Print binding and finishing workers', '51-5113', 14.9, 51.7, 19.7, 7.9, 5.5, 0.4, 0]
# ['Laundry and dry-cleaning workers', '51-6011', 33.8, 44.7, 13.2, 2.7, 4.9, 0.6, 0]
# ['Pressers, textile, garment, and related materials', '51-6021', 42.1, 37.9, 12.8, 3.3, 2.1, 1.9, 0]
# ['Sewing machine operators', '51-6031', 39.4, 35.9, 12.9, 5, 5.3, 1.2, 0.3]
# ['Shoe and leather workers and repairers(1)', '51-6041', 25.1, 37, 17.5, 9.5, 9.3, 1.6, 0]
# ['Shoe machine operators and tenders(1)', '51-6042', 25.1, 37, 17.5, 9.5, 9.3, 1.6, 0]
# ['Sewers, hand(1)', '51-6051', 24.8, 29.8, 17, 7.6, 17.4, 3, 0.4]
# ['Tailors, dressmakers, and custom sewers(1)', '51-6052', 24.8, 29.8, 17, 7.6, 17.4, 3, 0.4]
# ['Textile bleaching and dyeing machine operators and tenders(1)', '51-6061', 25, 46.7, 16.8, 3.1, 4.2, 4.3, 0]
# ['Textile cutting machine setters, operators, and tenders(1)', '51-6062', 25, 46.7, 16.8, 3.1, 4.2, 4.3, 0]
# ['Textile knitting and weaving machine setters, operators, and tenders(1)', '51-6063', 25, 46.7, 16.8, 3.1, 4.2, 4.3, 0]
# ['Textile winding, twisting, and drawing out machine setters, operators, and tenders(1)', '51-6064', 25, 46.7, 16.8, 3.1, 4.2, 4.3, 0]
# ['Extruding and forming machine setters, operators, and tenders, synthetic and glass fibers(1)', '51-6091', 18.1, 36.1, 24.9, 7.7, 10.7, 2.5, 0]
# ['Fabric and apparel patternmakers(1)', '51-6092', 18.1, 36.1, 24.9, 7.7, 10.7, 2.5, 0]
# ['Upholsterers', '51-6093', 34.4, 38.7, 15.5, 7.2, 2.5, 1.6, 0.1]
# ['Textile, apparel, and furnishings workers, all other(1)', '51-6099', 18.1, 36.1, 24.9, 7.7, 10.7, 2.5, 0]
# ['Cabinetmakers and bench carpenters', '51-7011', 17.3, 42.9, 20.1, 9.2, 7.7, 1.7, 1.1]
# ['Furniture finishers', '51-7021', 26.2, 44.7, 17.6, 6.5, 2.4, 1.1, 1.5]
# ['Model makers, wood(1)', '51-7031', 13.6, 33, 25.3, 9.8, 14, 3.8, 0.6]
# ['Patternmakers, wood(1)', '51-7032', 13.6, 33, 25.3, 9.8, 14, 3.8, 0.6]
# ['Sawing machine setters, operators, and tenders, wood', '51-7041', 35.6, 46.5, 12.5, 4.2, 1.1, 0, 0]
# ['Woodworking machine setters, operators, and tenders, except sawing', '51-7042', 23.4, 45.8, 22.4, 6.2, 1.9, 0.2, 0]
# ['Woodworkers, all other(1)', '51-7099', 13.6, 33, 25.3, 9.8, 14, 3.8, 0.6]
# ['Nuclear power reactor operators(1)', '51-8011', 2.4, 27.5, 31.8, 17.5, 18.8, 1.3, 0.6]
# ['Power distributors and dispatchers(1)', '51-8012', 2.4, 27.5, 31.8, 17.5, 18.8, 1.3, 0.6]
# ['Power plant operators(1)', '51-8013', 2.4, 27.5, 31.8, 17.5, 18.8, 1.3, 0.6]
# ['Stationary engineers and boiler operators', '51-8021', 5.9, 31.5, 26, 12.2, 16.6, 6.2, 1.6]
# ['Water and wastewater treatment plant and system operators', '51-8031', 2.6, 36.6, 33.1, 13.9, 12.3, 1.1, 0.3]
# ['Chemical plant and system operators(1)', '51-8091', 8.3, 34.5, 34.6, 11.3, 10.4, 0.5, 0.4]
# ['Gas plant operators(1)', '51-8092', 8.3, 34.5, 34.6, 11.3, 10.4, 0.5, 0.4]
# ['Petroleum pump system operators, refinery operators, and gaugers(1)', '51-8093', 8.3, 34.5, 34.6, 11.3, 10.4, 0.5, 0.4]
# ['Plant and system operators, all other(1)', '51-8099', 8.3, 34.5, 34.6, 11.3, 10.4, 0.5, 0.4]
# ['Chemical equipment operators and tenders(1)', '51-9011', 5.8, 33.3, 24.6, 9.9, 22.9, 3.5, 0.1]
# ['Separating, filtering, clarifying, precipitating, and still machine setters, operators, and tenders(1)', '51-9012', 5.8, 33.3, 24.6, 9.9, 22.9, 3.5, 0.1]
# ['Crushing, grinding, and polishing machine setters, operators, and tenders(1)', '51-9021', 20.3, 47.1, 20.3, 8.2, 3.4, 0.6, 0.1]
# ['Grinding and polishing workers, hand(1)', '51-9022', 20.3, 47.1, 20.3, 8.2, 3.4, 0.6, 0.1]
# ['Mixing and blending machine setters, operators, and tenders(1)', '51-9023', 20.3, 47.1, 20.3, 8.2, 3.4, 0.6, 0.1]
# ['Cutters and trimmers, hand(1)', '51-9031', 32.8, 40.8, 17.8, 3.1, 4, 1.4, 0.1]
# ['Cutting and slicing machine setters, operators, and tenders(1)', '51-9032', 32.8, 40.8, 17.8, 3.1, 4, 1.4, 0.1]
# ['Extruding, forming, pressing, and compacting machine setters, operators, and tenders', '51-9041', 15.3, 54.9, 20.1, 6.1, 3.1, 0.5, 0]
# ['Furnace, kiln, oven, drier, and kettle operators and tenders', '51-9051', 8, 48.3, 28.2, 6.3, 8.7, 0.4, 0]
# ['Inspectors, testers, sorters, samplers, and weighers', '51-9061', 9.1, 37.2, 26.3, 11.7, 12.4, 2.6, 0.6]
# ['Jewelers and precious stone and metal workers', '51-9071', 11.8, 26.6, 20.6, 9.8, 24, 5.8, 1.3]
# ['Dental laboratory technicians(1)', '51-9081', 4.2, 25.7, 36, 16.9, 14.5, 1.9, 0.7]
# ['Medical appliance technicians(1)', '51-9082', 4.2, 25.7, 36, 16.9, 14.5, 1.9, 0.7]
# ['Ophthalmic laboratory technicians(1)', '51-9083', 4.2, 25.7, 36, 16.9, 14.5, 1.9, 0.7]
# ['Packaging and filling machine operators and tenders', '51-9111', 31, 42.1, 16.3, 4.8, 4.8, 0.8, 0.2]
# ['Painting, coating, and decorating workers(1)', '51-9123', 20, 46.7, 21.9, 6.7, 4.3, 0.3, 0.1]
# ['Coating, painting, and spraying machine setters, operators, and tenders(1)', '51-9124', 20, 46.7, 21.9, 6.7, 4.3, 0.3, 0.1]
# ['Semiconductor processing technicians(1)', '51-9141', 18.4, 46.6, 20.8, 6.5, 6.4, 1.1, 0.2]
# ['Photographic process workers and processing machine operators', '51-9151', 3.6, 14.4, 17.9, 6.1, 48.1, 9.1, 0.9]
# ['Computer numerically controlled tool operators(1)', '51-9161', 9.4, 39.4, 29.7, 12.8, 7.6, 0.8, 0.2]
# ['Computer numerically controlled tool programmers(1)', '51-9162', 9.4, 39.4, 29.7, 12.8, 7.6, 0.8, 0.2]
# ['Adhesive bonding machine operators and tenders', '51-9191', 14.3, 47.7, 21, 11.3, 2.3, 3.5, 0]
# ['Cleaning, washing, and metal pickling equipment operators and tenders(1)', '51-9192', 18.4, 46.6, 20.8, 6.5, 6.4, 1.1, 0.2]
# ['Cooling and freezing equipment operators and tenders(1)', '51-9193', 18.4, 46.6, 20.8, 6.5, 6.4, 1.1, 0.2]
# ['Etchers and engravers', '51-9194', 16.5, 21.9, 20.9, 7.7, 32.2, 0.8, 0]
# ['Molders, shapers, and casters, except metal and plastic', '51-9195', 22.7, 31.2, 15.8, 7.6, 18.6, 3.1, 1]
# ['Paper goods machine setters, operators, and tenders', '51-9196', 14.5, 42.4, 23.9, 13.5, 5.7, 0, 0]
# ['Tire builders', '51-9197', 2.3, 48, 36.9, 8.2, 3.6, 1, 0]
# ['Helpers--production workers', '51-9198', 22.4, 49.5, 15, 4.6, 5.7, 2.1, 0.7]
# ['Production workers, all other(1)', '51-9199', 17.6, 46, 21.5, 7, 6.6, 1.1, 0.2]
# ['Aircraft cargo handling supervisors(1)', '53-1041', 6.7, 37, 28.9, 10.5, 14.6, 2.1, 0.2]
# ['First-line supervisors of transportation and material-moving workers, except aircraft cargo handling supervisors(1)', '53-1047', 6.7, 37, 28.9, 10.5, 14.6, 2.1, 0.2]
# ['Airline pilots, copilots, and flight engineers(1)', '53-2011', 0.8, 4.8, 14.1, 7.9, 56.9, 12.9, 2.6]
# ['Commercial pilots(1)', '53-2012', 0.8, 4.8, 14.1, 7.9, 56.9, 12.9, 2.6]
# ['Air traffic controllers(1)', '53-2021', 0.4, 11.9, 30.6, 15.3, 35, 6.3, 0.7]
# ['Airfield operations specialists(1)', '53-2022', 0.4, 11.9, 30.6, 15.3, 35, 6.3, 0.7]
# ['Flight attendants', '53-2031', 0.7, 15.6, 35, 11.2, 32, 4.3, 1.3]
# ['Ambulance drivers and attendants, except emergency medical technicians', '53-3011', 1, 45, 32.3, 10.3, 10.5, 0.9, 0]
# ['Driver/sales workers(1)', '53-3031', 15.5, 47.2, 23.1, 6.7, 6.4, 0.9, 0.3]
# ['Heavy and tractor-trailer truck drivers(1)', '53-3032', 15.5, 47.2, 23.1, 6.7, 6.4, 0.9, 0.3]
# ['Light truck drivers(1)', '53-3033', 15.5, 47.2, 23.1, 6.7, 6.4, 0.9, 0.3]
# ['Bus drivers, transit and intercity', '53-3052', 8.4, 40.8, 29.6, 9.9, 9.3, 1.7, 0.4]
# ['Passenger vehicle drivers, except bus drivers, transit and intercity(1)', '53-3058', 10.5, 36.3, 26.8, 8.7, 13.7, 3.1, 0.9]
# ['Motor vehicle operators, all other', '53-3099', 11.1, 36.1, 28.3, 10, 11.1, 2.9, 0.5]
# ['Locomotive engineers(1)', '53-4011', 1.5, 41.1, 34.6, 10.1, 10.3, 2.1, 0.3]
# ['Rail yard engineers, dinkey operators, and hostlers(1)', '53-4013', 1.5, 41.1, 34.6, 10.1, 10.3, 2.1, 0.3]
# ['Railroad brake, signal, and switch operators and locomotive firers(1)', '53-4022', 3.3, 35.8, 36.9, 9, 11.4, 3.5, 0.2]
# ['Railroad conductors and yardmasters', '53-4031', 1.7, 39.9, 35.7, 10.3, 11.6, 0.7, 0]
# ['Subway and streetcar operators(1)', '53-4041', 3.3, 35.8, 36.9, 9, 11.4, 3.5, 0.2]
# ['Rail transportation workers, all other(1)', '53-4099', 3.3, 35.8, 36.9, 9, 11.4, 3.5, 0.2]
# ['Sailors and marine oilers(1)', '53-5011', 8, 43.7, 24.1, 6.6, 14.1, 3.3, 0.3]
# ['Captains, mates, and pilots of water vessels(1)', '53-5021', 8.7, 33.5, 29.1, 5.9, 17.4, 4.5, 0.9]
# ['Motorboat operators(1)', '53-5022', 8.7, 33.5, 29.1, 5.9, 17.4, 4.5, 0.9]
# ['Ship engineers(1)', '53-5031', 8, 43.7, 24.1, 6.6, 14.1, 3.3, 0.3]
# ['Bridge and lock tenders(1)', '53-6011', 5.6, 40, 24.7, 12, 15.7, 1.7, 0.3]
# ['Parking attendants', '53-6021', 11.7, 44.3, 23.6, 7.8, 10.1, 1.7, 0.8]
# ['Automotive and watercraft service attendants(1)', '53-6031', 15, 44.6, 25, 8.3, 6.1, 0.9, 0]
# ['Traffic technicians(1)', '53-6041', 5.6, 40, 24.7, 12, 15.7, 1.7, 0.3]
# ['Transportation inspectors', '53-6051', 5.7, 28.2, 29.6, 13.2, 20.5, 2, 0.8]
# ['Passenger attendants', '53-6061', 14.1, 42.5, 25.5, 9, 6.8, 2.1, 0]
# ['Aircraft service attendants and transportation workers, all other(1)', '53-6098', 12.4, 43.4, 25, 9.3, 8.8, 1.1, 0.1]
# ['Conveyor operators and tenders(1)', '53-7011', 16.9, 56.9, 21.5, 2.6, 1.7, 0.3, 0]
# ['Crane and tower operators', '53-7021', 12.2, 54.3, 21, 7.2, 4.8, 0.3, 0.2]
# ['Dredge operators(1)', '53-7031', 16.9, 56.9, 21.5, 2.6, 1.7, 0.3, 0]
# ['Hoist and winch operators(1)', '53-7041', 16.9, 56.9, 21.5, 2.6, 1.7, 0.3, 0]
# ['Industrial truck and tractor operators', '53-7051', 18.6, 51, 20.9, 5.5, 3.4, 0.4, 0.2]
# ['Cleaners of vehicles and equipment', '53-7061', 27.1, 44.8, 16.5, 6.1, 4.7, 0.7, 0.2]
# ['Laborers and freight, stock, and material movers, hand', '53-7062', 16.8, 47.7, 21.5, 6.2, 6.5, 1, 0.3]
# ['Machine feeders and offbearers', '53-7063', 19.2, 51.9, 13.7, 5.5, 8.1, 1.1, 0.6]
# ['Packers and packagers, hand', '53-7064', 30.3, 40.5, 16.6, 5.7, 5.8, 0.7, 0.4]
# ['Stockers and order fillers', '53-7065', 13.2, 42.8, 25.2, 8.1, 9, 1.4, 0.3]
# ['Gas compressor and gas pumping station operators(1)', '53-7071', 15.8, 40.1, 20.2, 8.5, 12.9, 2.5, 0.1]
# ['Pump operators, except wellhead pumpers(1)', '53-7072', 15.8, 40.1, 20.2, 8.5, 12.9, 2.5, 0.1]
# ['Wellhead pumpers(1)', '53-7073', 15.8, 40.1, 20.2, 8.5, 12.9, 2.5, 0.1]
# ['Refuse and recyclable material collectors', '53-7081', 26.4, 44.7, 15, 6.1, 7.3, 0.3, 0.1]
# ['Tank car, truck, and ship loaders(1)', '53-7121', 17.4, 49.6, 19.6, 6.2, 5.8, 1.4, 0.1]
# ['Material moving workers, all other(1)', '53-7199', 17.4, 49.6, 19.6, 6.2, 5.8, 1.4, 0.1]
# ['Footnotes:', None, None, None, None, None, None, None, None]
# ['(1) This occupation is not an exact match with ACS; see https://www.bls.gov/emp/classifications-crosswalks/NEM-OccCode-ACS-Crosswalk.xlsx for details', None, None, None, None, None, None, None, None]
# ['Data Source: 2019 American Community Survey Public Use Microdata, U.S. Department of Commerce, U.S. Census Bureau', None, None, None, None, None, None, None, None]
# ['Table Source: Employment Projections program, U.S. Bureau of Labor Statistics', None, None, None, None, None, None, None, None]

# %%
# This data table is Table 5.4 Education and training assignments by detailed occupation, 2023
processTable(table3p)
print("\n")
# Out:
# ['Table 5.4 Education and training assignments by detailed occupation, 2019', None, None, None, None]
# ['2019 National Employment Matrix title', '2019 National Employment Matrix code', 'Typical education needed for entry', 'Work experience in a related occupation', 'Typical on-the-job training needed to attain competency in the occupation']
# ['Chief executives', '11-1011', "Bachelor's degree", '5 years or more', 'None']
# ['General and operations managers', '11-1021', "Bachelor's degree", '5 years or more', 'None']
# ['Legislators', '11-1031', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Advertising and promotions managers', '11-2011', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Marketing managers', '11-2021', "Bachelor's degree", '5 years or more', 'None']
# ['Sales managers', '11-2022', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Public relations and fundraising managers', '11-2030', "Bachelor's degree", '5 years or more', 'None']
# ['Administrative services and facilities managers', '11-3010', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Computer and information systems managers', '11-3021', "Bachelor's degree", '5 years or more', 'None']
# ['Financial managers', '11-3031', "Bachelor's degree", '5 years or more', 'None']
# ['Industrial production managers', '11-3051', "Bachelor's degree", '5 years or more', 'None']
# ['Purchasing managers', '11-3061', "Bachelor's degree", '5 years or more', 'None']
# ['Transportation, storage, and distribution managers', '11-3071', 'High school diploma or equivalent', '5 years or more', 'None']
# ['Compensation and benefits managers', '11-3111', "Bachelor's degree", '5 years or more', 'None']
# ['Human resources managers', '11-3121', "Bachelor's degree", '5 years or more', 'None']
# ['Training and development managers', '11-3131', "Bachelor's degree", '5 years or more', 'None']
# ['Farmers, ranchers, and other agricultural managers', '11-9013', 'High school diploma or equivalent', '5 years or more', 'None']
# ['Construction managers', '11-9021', "Bachelor's degree", 'None', 'Moderate-term on-the-job training']
# ['Education and childcare administrators, preschool and daycare', '11-9031', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Education administrators, kindergarten through secondary', '11-9032', "Master's degree", '5 years or more', 'None']
# ['Education administrators, postsecondary', '11-9033', "Master's degree", 'Less than 5 years', 'None']
# ['Education administrators, all other', '11-9039', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Architectural and engineering managers', '11-9041', "Bachelor's degree", '5 years or more', 'None']
# ['Food service managers', '11-9051', 'High school diploma or equivalent', 'Less than 5 years', 'None']
# ['Gambling managers', '11-9071', 'High school diploma or equivalent', 'Less than 5 years', 'None']
# ['Lodging managers', '11-9081', 'High school diploma or equivalent', 'Less than 5 years', 'None']
# ['Medical and health services managers', '11-9111', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Natural sciences managers', '11-9121', "Bachelor's degree", '5 years or more', 'None']
# ['Postmasters and mail superintendents', '11-9131', 'High school diploma or equivalent', 'Less than 5 years', 'Moderate-term on-the-job training']
# ['Property, real estate, and community association managers', '11-9141', 'High school diploma or equivalent', 'Less than 5 years', 'None']
# ['Social and community service managers', '11-9151', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Emergency management directors', '11-9161', "Bachelor's degree", '5 years or more', 'None']
# ['Funeral home managers', '11-9171', "Associate's degree", 'Less than 5 years', 'None']
# ['Personal service managers, all other; entertainment and recreation managers, except gambling; and managers, all other', '11-9198', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Agents and business managers of artists, performers, and athletes', '13-1011', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Buyers and purchasing agents', '13-1020', "Bachelor's degree", 'None', 'Moderate-term on-the-job training']
# ['Claims adjusters, examiners, and investigators', '13-1031', 'High school diploma or equivalent', 'None', 'Long-term on-the-job training']
# ['Insurance appraisers, auto damage', '13-1032', 'Postsecondary nondegree award', 'None', 'Moderate-term on-the-job training']
# ['Compliance officers', '13-1041', "Bachelor's degree", 'None', 'Moderate-term on-the-job training']
# ['Cost estimators', '13-1051', "Bachelor's degree", 'None', 'Moderate-term on-the-job training']
# ['Human resources specialists', '13-1071', "Bachelor's degree", 'None', 'None']
# ['Farm labor contractors', '13-1074', 'No formal educational credential', 'Less than 5 years', 'Short-term on-the-job training']
# ['Labor relations specialists', '13-1075', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Logisticians', '13-1081', "Bachelor's degree", 'None', 'None']
# ['Management analysts', '13-1111', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Meeting, convention, and event planners', '13-1121', "Bachelor's degree", 'None', 'None']
# ['Fundraisers', '13-1131', "Bachelor's degree", 'None', 'None']
# ['Compensation, benefits, and job analysis specialists', '13-1141', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Training and development specialists', '13-1151', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Market research analysts and marketing specialists', '13-1161', "Bachelor's degree", 'None', 'None']
# ['Project management specialists and business operations specialists, all other', '13-1198', "Bachelor's degree", 'None', 'None']
# ['Accountants and auditors', '13-2011', "Bachelor's degree", 'None', 'None']
# ['Property appraisers and assessors', '13-2020', "Bachelor's degree", 'None', 'Long-term on-the-job training']
# ['Budget analysts', '13-2031', "Bachelor's degree", 'None', 'None']
# ['Credit analysts', '13-2041', "Bachelor's degree", 'None', 'None']
# ['Personal financial advisors', '13-2052', "Bachelor's degree", 'None', 'Long-term on-the-job training']
# ['Insurance underwriters', '13-2053', "Bachelor's degree", 'None', 'Moderate-term on-the-job training']
# ['Financial examiners', '13-2061', "Bachelor's degree", 'None', 'Long-term on-the-job training']
# ['Credit counselors', '13-2071', "Bachelor's degree", 'None', 'Moderate-term on-the-job training']
# ['Loan officers', '13-2072', "Bachelor's degree", 'None', 'Moderate-term on-the-job training']
# ['Tax examiners and collectors, and revenue agents', '13-2081', "Bachelor's degree", 'None', 'Moderate-term on-the-job training']
# ['Tax preparers', '13-2082', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Financial and investment analysts, financial risk specialists, and financial specialists, all other', '13-2098', "Bachelor's degree", 'None', 'None']
# ['Computer systems analysts', '15-1211', "Bachelor's degree", 'None', 'None']
# ['Information security analysts', '15-1212', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Computer and information research scientists', '15-1221', "Master's degree", 'None', 'None']
# ['Computer network support specialists', '15-1231', "Associate's degree", 'None', 'None']
# ['Computer user support specialists', '15-1232', 'Some college, no degree', 'None', 'None']
# ['Computer network architects', '15-1241', "Bachelor's degree", '5 years or more', 'None']
# ['Network and computer systems administrators', '15-1244', "Bachelor's degree", 'None', 'None']
# ['Database administrators and architects', '15-1245', "Bachelor's degree", 'None', 'None']
# ['Computer programmers', '15-1251', "Bachelor's degree", 'None', 'None']
# ['Software developers and software quality assurance analysts and testers', '15-1256', "Bachelor's degree", 'None', 'None']
# ['Web developers and digital interface designers', '15-1257', "Associate's degree", 'None', 'None']
# ['Computer occupations, all other', '15-1299', "Bachelor's degree", 'None', 'None']
# ['Actuaries', '15-2011', "Bachelor's degree", 'None', 'Long-term on-the-job training']
# ['Mathematicians', '15-2021', "Master's degree", 'None', 'None']
# ['Operations research analysts', '15-2031', "Bachelor's degree", 'None', 'None']
# ['Statisticians', '15-2041', "Master's degree", 'None', 'None']
# ['Data scientists and mathematical science occupations, all other', '15-2098', "Bachelor's degree", 'None', 'None']
# ['Architects, except landscape and naval', '17-1011', "Bachelor's degree", 'None', 'Internship/residency']
# ['Landscape architects', '17-1012', "Bachelor's degree", 'None', 'Internship/residency']
# ['Cartographers and photogrammetrists', '17-1021', "Bachelor's degree", 'None', 'None']
# ['Surveyors', '17-1022', "Bachelor's degree", 'None', 'Internship/residency']
# ['Aerospace engineers', '17-2011', "Bachelor's degree", 'None', 'None']
# ['Agricultural engineers', '17-2021', "Bachelor's degree", 'None', 'None']
# ['Bioengineers and biomedical engineers', '17-2031', "Bachelor's degree", 'None', 'None']
# ['Chemical engineers', '17-2041', "Bachelor's degree", 'None', 'None']
# ['Civil engineers', '17-2051', "Bachelor's degree", 'None', 'None']
# ['Computer hardware engineers', '17-2061', "Bachelor's degree", 'None', 'None']
# ['Electrical engineers', '17-2071', "Bachelor's degree", 'None', 'None']
# ['Electronics engineers, except computer', '17-2072', "Bachelor's degree", 'None', 'None']
# ['Environmental engineers', '17-2081', "Bachelor's degree", 'None', 'None']
# ['Health and safety engineers, except mining safety engineers and inspectors', '17-2111', "Bachelor's degree", 'None', 'None']
# ['Industrial engineers', '17-2112', "Bachelor's degree", 'None', 'None']
# ['Marine engineers and naval architects', '17-2121', "Bachelor's degree", 'None', 'None']
# ['Materials engineers', '17-2131', "Bachelor's degree", 'None', 'None']
# ['Mechanical engineers', '17-2141', "Bachelor's degree", 'None', 'None']
# ['Mining and geological engineers, including mining safety engineers', '17-2151', "Bachelor's degree", 'None', 'None']
# ['Nuclear engineers', '17-2161', "Bachelor's degree", 'None', 'None']
# ['Petroleum engineers', '17-2171', "Bachelor's degree", 'None', 'None']
# ['Engineers, all other', '17-2199', "Bachelor's degree", 'None', 'None']
# ['Architectural and civil drafters', '17-3011', "Associate's degree", 'None', 'None']
# ['Electrical and electronics drafters', '17-3012', "Associate's degree", 'None', 'None']
# ['Mechanical drafters', '17-3013', "Associate's degree", 'None', 'None']
# ['Drafters, all other', '17-3019', "Associate's degree", 'None', 'None']
# ['Aerospace engineering and operations technologists and technicians', '17-3021', "Associate's degree", 'None', 'None']
# ['Civil engineering technologists and technicians', '17-3022', "Associate's degree", 'None', 'None']
# ['Electrical and electronic engineering technologists and technicians', '17-3023', "Associate's degree", 'None', 'None']
# ['Electro-mechanical and mechatronics technologists and technicians', '17-3024', "Associate's degree", 'None', 'None']
# ['Environmental engineering technologists and technicians', '17-3025', "Associate's degree", 'None', 'None']
# ['Industrial engineering technologists and technicians', '17-3026', "Associate's degree", 'None', 'None']
# ['Mechanical engineering technologists and technicians', '17-3027', "Associate's degree", 'None', 'None']
# ['Surveying and mapping technicians', '17-3031', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Calibration technologists and technicians and engineering technologists and technicians, except drafters, all other', '17-3098', "Associate's degree", 'None', 'None']
# ['Animal scientists', '19-1011', "Bachelor's degree", 'None', 'None']
# ['Food scientists and technologists', '19-1012', "Bachelor's degree", 'None', 'None']
# ['Soil and plant scientists', '19-1013', "Bachelor's degree", 'None', 'None']
# ['Biochemists and biophysicists', '19-1021', 'Doctoral or professional degree', 'None', 'None']
# ['Microbiologists', '19-1022', "Bachelor's degree", 'None', 'None']
# ['Zoologists and wildlife biologists', '19-1023', "Bachelor's degree", 'None', 'None']
# ['Biological scientists, all other', '19-1029', "Bachelor's degree", 'None', 'None']
# ['Conservation scientists', '19-1031', "Bachelor's degree", 'None', 'None']
# ['Foresters', '19-1032', "Bachelor's degree", 'None', 'None']
# ['Epidemiologists', '19-1041', "Master's degree", 'None', 'None']
# ['Medical scientists, except epidemiologists', '19-1042', 'Doctoral or professional degree', 'None', 'None']
# ['Life scientists, all other', '19-1099', "Bachelor's degree", 'None', 'None']
# ['Astronomers', '19-2011', 'Doctoral or professional degree', 'None', 'None']
# ['Physicists', '19-2012', 'Doctoral or professional degree', 'None', 'None']
# ['Atmospheric and space scientists', '19-2021', "Bachelor's degree", 'None', 'None']
# ['Chemists', '19-2031', "Bachelor's degree", 'None', 'None']
# ['Materials scientists', '19-2032', "Bachelor's degree", 'None', 'None']
# ['Environmental scientists and specialists, including health', '19-2041', "Bachelor's degree", 'None', 'None']
# ['Geoscientists, except hydrologists and geographers', '19-2042', "Bachelor's degree", 'None', 'None']
# ['Hydrologists', '19-2043', "Bachelor's degree", 'None', 'None']
# ['Physical scientists, all other', '19-2099', "Bachelor's degree", 'None', 'None']
# ['Economists', '19-3011', "Master's degree", 'None', 'None']
# ['Survey researchers', '19-3022', "Master's degree", 'None', 'None']
# ['Clinical, counseling, and school psychologists', '19-3031', 'Doctoral or professional degree', 'None', 'Internship/residency']
# ['Industrial-organizational psychologists', '19-3032', "Master's degree", 'None', 'Internship/residency']
# ['Psychologists, all other', '19-3039', "Master's degree", 'None', 'Internship/residency']
# ['Sociologists', '19-3041', "Master's degree", 'None', 'None']
# ['Urban and regional planners', '19-3051', "Master's degree", 'None', 'None']
# ['Anthropologists and archeologists', '19-3091', "Master's degree", 'None', 'None']
# ['Geographers', '19-3092', "Bachelor's degree", 'None', 'None']
# ['Historians', '19-3093', "Master's degree", 'None', 'None']
# ['Political scientists', '19-3094', "Master's degree", 'None', 'None']
# ['Social scientists and related workers, all other', '19-3099', "Bachelor's degree", 'None', 'None']
# ['Agricultural and food science technicians', '19-4010', "Associate's degree", 'None', 'Moderate-term on-the-job training']
# ['Biological technicians', '19-4021', "Bachelor's degree", 'None', 'None']
# ['Chemical technicians', '19-4031', "Associate's degree", 'None', 'Moderate-term on-the-job training']
# ['Environmental science and protection technicians, including health', '19-4042', "Associate's degree", 'None', 'None']
# ['Geological and hydrologic technicians', '19-4045', "Associate's degree", 'None', 'Moderate-term on-the-job training']
# ['Nuclear technicians', '19-4051', "Associate's degree", 'None', 'Moderate-term on-the-job training']
# ['Social science research assistants', '19-4061', "Bachelor's degree", 'None', 'None']
# ['Forest and conservation technicians', '19-4071', "Associate's degree", 'None', 'None']
# ['Forensic science technicians', '19-4092', "Bachelor's degree", 'None', 'Moderate-term on-the-job training']
# ['Life, physical, and social science technicians, all other', '19-4099', "Associate's degree", 'None', 'None']
# ['Occupational health and safety specialists', '19-5011', "Bachelor's degree", 'None', 'None']
# ['Occupational health and safety technicians', '19-5012', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Educational, guidance, and career counselors and advisors', '21-1012', "Master's degree", 'None', 'None']
# ['Marriage and family therapists', '21-1013', "Master's degree", 'None', 'Internship/residency']
# ['Rehabilitation counselors', '21-1015', "Master's degree", 'None', 'None']
# ['Substance abuse, behavioral disorder, and mental health counselors', '21-1018', "Bachelor's degree", 'None', 'None']
# ['Counselors, all other', '21-1019', "Master's degree", 'None', 'None']
# ['Child, family, and school social workers', '21-1021', "Bachelor's degree", 'None', 'None']
# ['Healthcare social workers', '21-1022', "Master's degree", 'None', 'Internship/residency']
# ['Mental health and substance abuse social workers', '21-1023', "Master's degree", 'None', 'Internship/residency']
# ['Social workers, all other', '21-1029', "Bachelor's degree", 'None', 'None']
# ['Health education specialists', '21-1091', "Bachelor's degree", 'None', 'None']
# ['Probation officers and correctional treatment specialists', '21-1092', "Bachelor's degree", 'None', 'Short-term on-the-job training']
# ['Social and human service assistants', '21-1093', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Community health workers', '21-1094', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Community and social service specialists, all other', '21-1099', "Bachelor's degree", 'None', 'None']
# ['Clergy', '21-2011', "Bachelor's degree", 'None', 'Moderate-term on-the-job training']
# ['Directors, religious activities and education', '21-2021', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Religious workers, all other', '21-2099', "Bachelor's degree", 'None', 'None']
# ['Lawyers', '23-1011', 'Doctoral or professional degree', 'None', 'None']
# ['Judicial law clerks', '23-1012', 'Doctoral or professional degree', 'None', 'None']
# ['Administrative law judges, adjudicators, and hearing officers', '23-1021', 'Doctoral or professional degree', '5 years or more', 'Short-term on-the-job training']
# ['Arbitrators, mediators, and conciliators', '23-1022', "Bachelor's degree", 'Less than 5 years', 'Moderate-term on-the-job training']
# ['Judges, magistrate judges, and magistrates', '23-1023', 'Doctoral or professional degree', '5 years or more', 'Short-term on-the-job training']
# ['Paralegals and legal assistants', '23-2011', "Associate's degree", 'None', 'None']
# ['Title examiners, abstractors, and searchers', '23-2093', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Legal support workers, all other', '23-2099', "Associate's degree", 'None', 'None']
# ['Business teachers, postsecondary', '25-1011', 'Doctoral or professional degree', 'None', 'None']
# ['Computer science teachers, postsecondary', '25-1021', 'Doctoral or professional degree', 'None', 'None']
# ['Mathematical science teachers, postsecondary', '25-1022', 'Doctoral or professional degree', 'None', 'None']
# ['Architecture teachers, postsecondary', '25-1031', 'Doctoral or professional degree', 'None', 'None']
# ['Engineering teachers, postsecondary', '25-1032', 'Doctoral or professional degree', 'None', 'None']
# ['Agricultural sciences teachers, postsecondary', '25-1041', 'Doctoral or professional degree', 'None', 'None']
# ['Biological science teachers, postsecondary', '25-1042', 'Doctoral or professional degree', 'None', 'None']
# ['Forestry and conservation science teachers, postsecondary', '25-1043', 'Doctoral or professional degree', 'None', 'None']
# ['Atmospheric, earth, marine, and space sciences teachers, postsecondary', '25-1051', 'Doctoral or professional degree', 'None', 'None']
# ['Chemistry teachers, postsecondary', '25-1052', 'Doctoral or professional degree', 'None', 'None']
# ['Environmental science teachers, postsecondary', '25-1053', 'Doctoral or professional degree', 'None', 'None']
# ['Physics teachers, postsecondary', '25-1054', 'Doctoral or professional degree', 'None', 'None']
# ['Anthropology and archeology teachers, postsecondary', '25-1061', 'Doctoral or professional degree', 'None', 'None']
# ['Area, ethnic, and cultural studies teachers, postsecondary', '25-1062', 'Doctoral or professional degree', 'None', 'None']
# ['Economics teachers, postsecondary', '25-1063', 'Doctoral or professional degree', 'None', 'None']
# ['Geography teachers, postsecondary', '25-1064', 'Doctoral or professional degree', 'None', 'None']
# ['Political science teachers, postsecondary', '25-1065', 'Doctoral or professional degree', 'None', 'None']
# ['Psychology teachers, postsecondary', '25-1066', 'Doctoral or professional degree', 'None', 'None']
# ['Sociology teachers, postsecondary', '25-1067', 'Doctoral or professional degree', 'None', 'None']
# ['Social sciences teachers, postsecondary, all other', '25-1069', 'Doctoral or professional degree', 'None', 'None']
# ['Health specialties teachers, postsecondary', '25-1071', 'Doctoral or professional degree', 'Less than 5 years', 'None']
# ['Nursing instructors and teachers, postsecondary', '25-1072', 'Doctoral or professional degree', 'Less than 5 years', 'None']
# ['Education teachers, postsecondary', '25-1081', 'Doctoral or professional degree', 'Less than 5 years', 'None']
# ['Library science teachers, postsecondary', '25-1082', 'Doctoral or professional degree', 'None', 'None']
# ['Criminal justice and law enforcement teachers, postsecondary', '25-1111', 'Doctoral or professional degree', 'None', 'None']
# ['Law teachers, postsecondary', '25-1112', 'Doctoral or professional degree', 'Less than 5 years', 'None']
# ['Social work teachers, postsecondary', '25-1113', 'Doctoral or professional degree', 'None', 'None']
# ['Art, drama, and music teachers, postsecondary', '25-1121', "Master's degree", 'None', 'None']
# ['Communications teachers, postsecondary', '25-1122', 'Doctoral or professional degree', 'None', 'None']
# ['English language and literature teachers, postsecondary', '25-1123', 'Doctoral or professional degree', 'None', 'None']
# ['Foreign language and literature teachers, postsecondary', '25-1124', 'Doctoral or professional degree', 'None', 'None']
# ['History teachers, postsecondary', '25-1125', 'Doctoral or professional degree', 'None', 'None']
# ['Philosophy and religion teachers, postsecondary', '25-1126', 'Doctoral or professional degree', 'None', 'None']
# ['Family and consumer sciences teachers, postsecondary', '25-1192', "Master's degree", 'None', 'None']
# ['Recreation and fitness studies teachers, postsecondary', '25-1193', 'Doctoral or professional degree', 'None', 'None']
# ['Career/technical education teachers, postsecondary', '25-1194', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Postsecondary teachers, all other', '25-1199', 'Doctoral or professional degree', 'None', 'None']
# ['Preschool teachers, except special education', '25-2011', "Associate's degree", 'None', 'None']
# ['Kindergarten teachers, except special education', '25-2012', "Bachelor's degree", 'None', 'None']
# ['Elementary school teachers, except special education', '25-2021', "Bachelor's degree", 'None', 'None']
# ['Middle school teachers, except special and career/technical education', '25-2022', "Bachelor's degree", 'None', 'None']
# ['Career/technical education teachers, middle school', '25-2023', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Secondary school teachers, except special and career/technical education', '25-2031', "Bachelor's degree", 'None', 'None']
# ['Career/technical education teachers, secondary school', '25-2032', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Special education teachers, preschool', '25-2051', "Bachelor's degree", 'None', 'None']
# ['Special education teachers, kindergarten and elementary school', '25-2052', "Bachelor's degree", 'None', 'None']
# ['Special education teachers, middle school', '25-2057', "Bachelor's degree", 'None', 'None']
# ['Special education teachers, secondary school', '25-2058', "Bachelor's degree", 'None', 'None']
# ['Special education teachers, all other', '25-2059', "Bachelor's degree", 'None', 'None']
# ['Adult basic education, adult secondary education, and English as a Second Language instructors', '25-3011', "Bachelor's degree", 'None', 'None']
# ['Self-enrichment teachers', '25-3021', 'High school diploma or equivalent', 'Less than 5 years', 'None']
# ['Substitute teachers, short-term', '25-3031', "Bachelor's degree", 'None', 'None']
# ['Tutors and teachers and instructors, all other', '25-3097', "Bachelor's degree", 'None', 'None']
# ['Archivists', '25-4011', "Master's degree", 'None', 'None']
# ['Curators', '25-4012', "Master's degree", 'None', 'None']
# ['Museum technicians and conservators', '25-4013', "Bachelor's degree", 'None', 'None']
# ['Librarians and media collections specialists', '25-4022', "Bachelor's degree", 'None', 'None']
# ['Library technicians', '25-4031', 'Postsecondary nondegree award', 'None', 'None']
# ['Farm and home management educators', '25-9021', "Master's degree", 'None', 'None']
# ['Instructional coordinators', '25-9031', "Master's degree", '5 years or more', 'None']
# ['Teaching assistants, postsecondary', '25-9044', "Bachelor's degree", 'None', 'None']
# ['Teaching assistants, except postsecondary', '25-9045', 'Some college, no degree', 'None', 'None']
# ['Educational instruction and library workers, all other', '25-9099', "Bachelor's degree", 'None', 'None']
# ['Art directors', '27-1011', "Bachelor's degree", '5 years or more', 'None']
# ['Craft artists', '27-1012', 'No formal educational credential', 'None', 'Long-term on-the-job training']
# ['Fine artists, including painters, sculptors, and illustrators', '27-1013', "Bachelor's degree", 'None', 'Long-term on-the-job training']
# ['Special effects artists and animators', '27-1014', "Bachelor's degree", 'None', 'None']
# ['Artists and related workers, all other', '27-1019', 'No formal educational credential', 'None', 'Long-term on-the-job training']
# ['Commercial and industrial designers', '27-1021', "Bachelor's degree", 'None', 'None']
# ['Fashion designers', '27-1022', "Bachelor's degree", 'None', 'None']
# ['Floral designers', '27-1023', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Graphic designers', '27-1024', "Bachelor's degree", 'None', 'None']
# ['Interior designers', '27-1025', "Bachelor's degree", 'None', 'None']
# ['Merchandise displayers and window trimmers', '27-1026', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Set and exhibit designers', '27-1027', "Bachelor's degree", 'None', 'None']
# ['Designers, all other', '27-1029', "Bachelor's degree", 'None', 'None']
# ['Actors', '27-2011', 'Some college, no degree', 'None', 'Long-term on-the-job training']
# ['Producers and directors', '27-2012', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Athletes and sports competitors', '27-2021', 'No formal educational credential', 'None', 'Long-term on-the-job training']
# ['Coaches and scouts', '27-2022', "Bachelor's degree", 'None', 'None']
# ['Umpires, referees, and other sports officials', '27-2023', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Dancers', '27-2031', 'No formal educational credential', 'None', 'Long-term on-the-job training']
# ['Choreographers', '27-2032', 'High school diploma or equivalent', '5 years or more', 'Long-term on-the-job training']
# ['Music directors and composers', '27-2041', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Musicians and singers', '27-2042', 'No formal educational credential', 'None', 'Long-term on-the-job training']
# ['Miscellaneous entertainers and performers, sports and related workers', '27-2090', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Broadcast announcers and radio disc jockeys', '27-3011', "Bachelor's degree", 'None', 'None']
# ['News analysts, reporters, and journalists', '27-3023', "Bachelor's degree", 'None', 'None']
# ['Public relations specialists', '27-3031', "Bachelor's degree", 'None', 'None']
# ['Editors', '27-3041', "Bachelor's degree", 'Less than 5 years', 'None']
# ['Technical writers', '27-3042', "Bachelor's degree", 'Less than 5 years', 'Short-term on-the-job training']
# ['Writers and authors', '27-3043', "Bachelor's degree", 'None', 'Long-term on-the-job training']
# ['Interpreters and translators', '27-3091', "Bachelor's degree", 'None', 'None']
# ['Court reporters and simultaneous captioners', '27-3092', 'Postsecondary nondegree award', 'None', 'Short-term on-the-job training']
# ['Media and communication workers, all other', '27-3099', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Audio and video technicians', '27-4011', 'Postsecondary nondegree award', 'None', 'Short-term on-the-job training']
# ['Broadcast technicians', '27-4012', "Associate's degree", 'None', 'Short-term on-the-job training']
# ['Sound engineering technicians', '27-4014', 'Postsecondary nondegree award', 'None', 'Short-term on-the-job training']
# ['Photographers', '27-4021', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Camera operators, television, video, and film', '27-4031', "Bachelor's degree", 'None', 'None']
# ['Film and video editors', '27-4032', "Bachelor's degree", 'None', 'None']
# ['Lighting technicians and media and communication equipment workers, all other', '27-4098', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Chiropractors', '29-1011', 'Doctoral or professional degree', 'None', 'None']
# ['Dentists, general', '29-1021', 'Doctoral or professional degree', 'None', 'None']
# ['Oral and maxillofacial surgeons', '29-1022', 'Doctoral or professional degree', 'None', 'Internship/residency']
# ['Orthodontists', '29-1023', 'Doctoral or professional degree', 'None', 'Internship/residency']
# ['Prosthodontists', '29-1024', 'Doctoral or professional degree', 'None', 'Internship/residency']
# ['Dentists, all other specialists', '29-1029', 'Doctoral or professional degree', 'None', 'Internship/residency']
# ['Dietitians and nutritionists', '29-1031', "Bachelor's degree", 'None', 'Internship/residency']
# ['Optometrists', '29-1041', 'Doctoral or professional degree', 'None', 'None']
# ['Pharmacists', '29-1051', 'Doctoral or professional degree', 'None', 'None']
# ['Physician assistants', '29-1071', "Master's degree", 'None', 'None']
# ['Podiatrists', '29-1081', 'Doctoral or professional degree', 'None', 'Internship/residency']
# ['Occupational therapists', '29-1122', "Master's degree", 'None', 'None']
# ['Physical therapists', '29-1123', 'Doctoral or professional degree', 'None', 'None']
# ['Radiation therapists', '29-1124', "Associate's degree", 'None', 'None']
# ['Recreational therapists', '29-1125', "Bachelor's degree", 'None', 'None']
# ['Respiratory therapists', '29-1126', "Associate's degree", 'None', 'None']
# ['Speech-language pathologists', '29-1127', "Master's degree", 'None', 'Internship/residency']
# ['Exercise physiologists', '29-1128', "Bachelor's degree", 'None', 'None']
# ['Therapists, all other', '29-1129', "Bachelor's degree", 'None', 'None']
# ['Veterinarians', '29-1131', 'Doctoral or professional degree', 'None', 'None']
# ['Registered nurses', '29-1141', "Bachelor's degree", 'None', 'None']
# ['Nurse anesthetists', '29-1151', "Master's degree", 'None', 'None']
# ['Nurse midwives', '29-1161', "Master's degree", 'None', 'None']
# ['Nurse practitioners', '29-1171', "Master's degree", 'None', 'None']
# ['Audiologists', '29-1181', 'Doctoral or professional degree', 'None', 'None']
# ['Anesthesiologists', '29-1211', 'Doctoral or professional degree', 'None', 'Internship/residency']
# ['Family medicine physicians', '29-1215', 'Doctoral or professional degree', 'None', 'Internship/residency']
# ['General internal medicine physicians', '29-1216', 'Doctoral or professional degree', 'None', 'Internship/residency']
# ['Obstetricians and gynecologists', '29-1218', 'Doctoral or professional degree', 'None', 'Internship/residency']
# ['Pediatricians, general', '29-1221', 'Doctoral or professional degree', 'None', 'Internship/residency']
# ['Psychiatrists', '29-1223', 'Doctoral or professional degree', 'None', 'Internship/residency']
# ['Physicians, all other; and ophthalmologists, except pediatric', '29-1228', 'Doctoral or professional degree', 'None', 'Internship/residency']
# ['Surgeons, except ophthalmologists', '29-1248', 'Doctoral or professional degree', 'None', 'Internship/residency']
# ['Dental hygienists', '29-1292', "Associate's degree", 'None', 'None']
# ['Acupuncturists and healthcare diagnosing or treating practitioners, all other', '29-1298', "Master's degree", 'None', 'None']
# ['Clinical laboratory technologists and technicians', '29-2010', "Bachelor's degree", 'None', 'None']
# ['Cardiovascular technologists and technicians', '29-2031', "Associate's degree", 'None', 'None']
# ['Diagnostic medical sonographers', '29-2032', "Associate's degree", 'None', 'None']
# ['Nuclear medicine technologists', '29-2033', "Associate's degree", 'None', 'None']
# ['Radiologic technologists and technicians', '29-2034', "Associate's degree", 'None', 'None']
# ['Magnetic resonance imaging technologists', '29-2035', "Associate's degree", 'Less than 5 years', 'None']
# ['Emergency medical technicians and paramedics', '29-2040', 'Postsecondary nondegree award', 'None', 'None']
# ['Dietetic technicians', '29-2051', "Associate's degree", 'None', 'None']
# ['Pharmacy technicians', '29-2052', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Psychiatric technicians', '29-2053', 'Postsecondary nondegree award', 'Less than 5 years', 'Short-term on-the-job training']
# ['Surgical technologists', '29-2055', 'Postsecondary nondegree award', 'None', 'None']
# ['Veterinary technologists and technicians', '29-2056', "Associate's degree", 'None', 'None']
# ['Ophthalmic medical technicians', '29-2057', 'Postsecondary nondegree award', 'None', 'None']
# ['Licensed practical and licensed vocational nurses', '29-2061', 'Postsecondary nondegree award', 'None', 'None']
# ['Opticians, dispensing', '29-2081', 'High school diploma or equivalent', 'None', 'Long-term on-the-job training']
# ['Orthotists and prosthetists', '29-2091', "Master's degree", 'None', 'Internship/residency']
# ['Hearing aid specialists', '29-2092', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Medical dosimetrists, medical records specialists, and health technologists and technicians, all other', '29-2098', 'Postsecondary nondegree award', 'None', 'None']
# ['Athletic trainers', '29-9091', "Bachelor's degree", 'None', 'None']
# ['Genetic counselors', '29-9092', "Master's degree", 'None', 'None']
# ['Health information technologists, medical registrars, surgical assistants, and healthcare practitioners and technical workers, all other', '29-9098', 'Postsecondary nondegree award', 'None', 'None']
# ['Home health and personal care aides', '31-1120', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Nursing assistants', '31-1131', 'Postsecondary nondegree award', 'None', 'None']
# ['Orderlies', '31-1132', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Psychiatric aides', '31-1133', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Occupational therapy assistants', '31-2011', "Associate's degree", 'None', 'None']
# ['Occupational therapy aides', '31-2012', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Physical therapist assistants', '31-2021', "Associate's degree", 'None', 'None']
# ['Physical therapist aides', '31-2022', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Massage therapists', '31-9011', 'Postsecondary nondegree award', 'None', 'None']
# ['Dental assistants', '31-9091', 'Postsecondary nondegree award', 'None', 'None']
# ['Medical assistants', '31-9092', 'Postsecondary nondegree award', 'None', 'None']
# ['Medical equipment preparers', '31-9093', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Medical transcriptionists', '31-9094', 'Postsecondary nondegree award', 'None', 'None']
# ['Pharmacy aides', '31-9095', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Veterinary assistants and laboratory animal caretakers', '31-9096', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Phlebotomists', '31-9097', 'Postsecondary nondegree award', 'None', 'None']
# ['Healthcare support workers, all other', '31-9099', 'High school diploma or equivalent', 'None', 'None']
# ['First-line supervisors of correctional officers', '33-1011', 'High school diploma or equivalent', 'Less than 5 years', 'None']
# ['First-line supervisors of police and detectives', '33-1012', 'High school diploma or equivalent', 'Less than 5 years', 'Moderate-term on-the-job training']
# ['First-line supervisors of firefighting and prevention workers', '33-1021', 'Postsecondary nondegree award', 'Less than 5 years', 'Moderate-term on-the-job training']
# ['Miscellaneous first-line supervisors, protective service workers', '33-1090', 'High school diploma or equivalent', 'Less than 5 years', 'None']
# ['Firefighters', '33-2011', 'Postsecondary nondegree award', 'None', 'Long-term on-the-job training']
# ['Fire inspectors and investigators', '33-2021', 'Postsecondary nondegree award', '5 years or more', 'Moderate-term on-the-job training']
# ['Forest fire inspectors and prevention specialists', '33-2022', 'High school diploma or equivalent', 'Less than 5 years', 'Moderate-term on-the-job training']
# ['Bailiffs', '33-3011', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Correctional officers and jailers', '33-3012', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Detectives and criminal investigators', '33-3021', 'High school diploma or equivalent', 'Less than 5 years', 'Moderate-term on-the-job training']
# ['Fish and game wardens', '33-3031', "Bachelor's degree", 'None', 'Moderate-term on-the-job training']
# ['Parking enforcement workers', '33-3041', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ["Police and sheriff's patrol officers", '33-3051', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Transit and railroad police', '33-3052', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Animal control workers', '33-9011', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Private detectives and investigators', '33-9021', 'High school diploma or equivalent', 'Less than 5 years', 'Moderate-term on-the-job training']
# ['Gambling surveillance officers and gambling investigators', '33-9031', 'High school diploma or equivalent', 'Less than 5 years', 'Moderate-term on-the-job training']
# ['Security guards', '33-9032', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Crossing guards and flaggers', '33-9091', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Lifeguards, ski patrol, and other recreational protective service workers', '33-9092', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Transportation security screeners', '33-9093', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['School bus monitors and protective service workers, all other', '33-9098', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Chefs and head cooks', '35-1011', 'High school diploma or equivalent', '5 years or more', 'None']
# ['First-line supervisors of food preparation and serving workers', '35-1012', 'High school diploma or equivalent', 'Less than 5 years', 'None']
# ['Cooks, fast food', '35-2011', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Cooks, institution and cafeteria', '35-2012', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Cooks, private household', '35-2013', 'Postsecondary nondegree award', 'Less than 5 years', 'None']
# ['Cooks, restaurant', '35-2014', 'No formal educational credential', 'Less than 5 years', 'Moderate-term on-the-job training']
# ['Cooks, short order', '35-2015', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Cooks, all other', '35-2019', 'No formal educational credential', 'None', 'Moderate-term on-the-job training']
# ['Food preparation workers', '35-2021', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Bartenders', '35-3011', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Fast food and counter workers', '35-3023', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Waiters and waitresses', '35-3031', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Food servers, nonrestaurant', '35-3041', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Dining room and cafeteria attendants and bartender helpers', '35-9011', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Dishwashers', '35-9021', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Hosts and hostesses, restaurant, lounge, and coffee shop', '35-9031', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Food preparation and serving related workers, all other', '35-9099', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['First-line supervisors of housekeeping and janitorial workers', '37-1011', 'High school diploma or equivalent', 'Less than 5 years', 'None']
# ['First-line supervisors of landscaping, lawn service, and groundskeeping workers', '37-1012', 'High school diploma or equivalent', 'Less than 5 years', 'None']
# ['Janitors and cleaners, except maids and housekeeping cleaners', '37-2011', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Maids and housekeeping cleaners', '37-2012', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Building cleaning workers, all other', '37-2019', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Pest control workers', '37-2021', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Landscaping and groundskeeping workers', '37-3011', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Pesticide handlers, sprayers, and applicators, vegetation', '37-3012', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Tree trimmers and pruners', '37-3013', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Grounds maintenance workers, all other', '37-3019', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['First-line supervisors of gambling services workers', '39-1013', 'High school diploma or equivalent', 'Less than 5 years', 'None']
# ['First-line supervisors of personal service and entertainment and recreation workers, except gambling services', '39-1098', 'High school diploma or equivalent', 'Less than 5 years', 'None']
# ['Animal trainers', '39-2011', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Animal caretakers', '39-2021', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Gambling dealers', '39-3011', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Gambling and sports book writers and runners', '39-3012', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Gambling service workers, all other', '39-3019', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Motion picture projectionists', '39-3021', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Ushers, lobby attendants, and ticket takers', '39-3031', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Amusement and recreation attendants', '39-3091', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Costume attendants', '39-3092', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Locker room, coatroom, and dressing room attendants', '39-3093', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Entertainment attendants and related workers, all other', '39-3099', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Embalmers', '39-4011', "Associate's degree", 'None', 'Long-term on-the-job training']
# ['Funeral attendants', '39-4021', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Morticians, undertakers, and funeral arrangers', '39-4031', "Associate's degree", 'None', 'Long-term on-the-job training']
# ['Barbers', '39-5011', 'Postsecondary nondegree award', 'None', 'None']
# ['Hairdressers, hairstylists, and cosmetologists', '39-5012', 'Postsecondary nondegree award', 'None', 'None']
# ['Makeup artists, theatrical and performance', '39-5091', 'Postsecondary nondegree award', 'None', 'None']
# ['Manicurists and pedicurists', '39-5092', 'Postsecondary nondegree award', 'None', 'None']
# ['Shampooers', '39-5093', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Skincare specialists', '39-5094', 'Postsecondary nondegree award', 'None', 'None']
# ['Baggage porters and bellhops', '39-6011', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Concierges', '39-6012', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Tour and travel guides', '39-7010', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Childcare workers', '39-9011', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Exercise trainers and group fitness instructors', '39-9031', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Recreation workers', '39-9032', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Residential advisors', '39-9041', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Crematory operators and personal care and service workers, all other', '39-9098', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['First-line supervisors of retail sales workers', '41-1011', 'High school diploma or equivalent', 'Less than 5 years', 'None']
# ['First-line supervisors of non-retail sales workers', '41-1012', 'High school diploma or equivalent', 'Less than 5 years', 'None']
# ['Cashiers', '41-2011', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Gambling change persons and booth cashiers', '41-2012', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Counter and rental clerks', '41-2021', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Parts salespersons', '41-2022', 'No formal educational credential', 'None', 'Moderate-term on-the-job training']
# ['Retail salespersons', '41-2031', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Advertising sales agents', '41-3011', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Insurance sales agents', '41-3021', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Securities, commodities, and financial services sales agents', '41-3031', "Bachelor's degree", 'None', 'Moderate-term on-the-job training']
# ['Travel agents', '41-3041', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Sales representatives of services, except advertising, insurance, financial services, and travel', '41-3091', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Sales representatives, wholesale and manufacturing, technical and scientific products', '41-4011', "Bachelor's degree", 'None', 'Moderate-term on-the-job training']
# ['Sales representatives, wholesale and manufacturing, except technical and scientific products', '41-4012', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ...
# ['Heat treating equipment setters, operators, and tenders, metal and plastic', '51-4191', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Layout workers, metal and plastic', '51-4192', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Plating machine setters, operators, and tenders, metal and plastic', '51-4193', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Tool grinders, filers, and sharpeners', '51-4194', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Metal workers and plastic workers, all other', '51-4199', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Prepress technicians and workers', '51-5111', 'Postsecondary nondegree award', 'None', 'None']
# ['Printing press operators', '51-5112', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Print binding and finishing workers', '51-5113', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Laundry and dry-cleaning workers', '51-6011', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Pressers, textile, garment, and related materials', '51-6021', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Sewing machine operators', '51-6031', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Shoe and leather workers and repairers', '51-6041', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Shoe machine operators and tenders', '51-6042', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Sewers, hand', '51-6051', 'No formal educational credential', 'None', 'Moderate-term on-the-job training']
# ['Tailors, dressmakers, and custom sewers', '51-6052', 'No formal educational credential', 'None', 'Moderate-term on-the-job training']
# ['Textile bleaching and dyeing machine operators and tenders', '51-6061', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Textile cutting machine setters, operators, and tenders', '51-6062', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Textile knitting and weaving machine setters, operators, and tenders', '51-6063', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Textile winding, twisting, and drawing out machine setters, operators, and tenders', '51-6064', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Extruding and forming machine setters, operators, and tenders, synthetic and glass fibers', '51-6091', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Fabric and apparel patternmakers', '51-6092', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Upholsterers', '51-6093', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Textile, apparel, and furnishings workers, all other', '51-6099', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Cabinetmakers and bench carpenters', '51-7011', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Furniture finishers', '51-7021', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Model makers, wood', '51-7031', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Patternmakers, wood', '51-7032', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Sawing machine setters, operators, and tenders, wood', '51-7041', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Woodworking machine setters, operators, and tenders, except sawing', '51-7042', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Woodworkers, all other', '51-7099', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Nuclear power reactor operators', '51-8011', 'High school diploma or equivalent', 'None', 'Long-term on-the-job training']
# ['Power distributors and dispatchers', '51-8012', 'High school diploma or equivalent', 'None', 'Long-term on-the-job training']
# ['Power plant operators', '51-8013', 'High school diploma or equivalent', 'None', 'Long-term on-the-job training']
# ['Stationary engineers and boiler operators', '51-8021', 'High school diploma or equivalent', 'None', 'Long-term on-the-job training']
# ['Water and wastewater treatment plant and system operators', '51-8031', 'High school diploma or equivalent', 'None', 'Long-term on-the-job training']
# ['Chemical plant and system operators', '51-8091', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Gas plant operators', '51-8092', 'High school diploma or equivalent', 'None', 'Long-term on-the-job training']
# ['Petroleum pump system operators, refinery operators, and gaugers', '51-8093', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Plant and system operators, all other', '51-8099', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Chemical equipment operators and tenders', '51-9011', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Separating, filtering, clarifying, precipitating, and still machine setters, operators, and tenders', '51-9012', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Crushing, grinding, and polishing machine setters, operators, and tenders', '51-9021', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Grinding and polishing workers, hand', '51-9022', 'No formal educational credential', 'None', 'Moderate-term on-the-job training']
# ['Mixing and blending machine setters, operators, and tenders', '51-9023', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Cutters and trimmers, hand', '51-9031', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Cutting and slicing machine setters, operators, and tenders', '51-9032', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Extruding, forming, pressing, and compacting machine setters, operators, and tenders', '51-9041', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Furnace, kiln, oven, drier, and kettle operators and tenders', '51-9051', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Inspectors, testers, sorters, samplers, and weighers', '51-9061', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Jewelers and precious stone and metal workers', '51-9071', 'High school diploma or equivalent', 'None', 'Long-term on-the-job training']
# ['Dental laboratory technicians', '51-9081', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Medical appliance technicians', '51-9082', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Ophthalmic laboratory technicians', '51-9083', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Packaging and filling machine operators and tenders', '51-9111', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Painting, coating, and decorating workers', '51-9123', 'No formal educational credential', 'None', 'Moderate-term on-the-job training']
# ['Coating, painting, and spraying machine setters, operators, and tenders', '51-9124', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Semiconductor processing technicians', '51-9141', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Photographic process workers and processing machine operators', '51-9151', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Computer numerically controlled tool operators', '51-9161', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Computer numerically controlled tool programmers', '51-9162', 'Postsecondary nondegree award', 'None', 'Moderate-term on-the-job training']
# ['Adhesive bonding machine operators and tenders', '51-9191', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Cleaning, washing, and metal pickling equipment operators and tenders', '51-9192', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Cooling and freezing equipment operators and tenders', '51-9193', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Etchers and engravers', '51-9194', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Molders, shapers, and casters, except metal and plastic', '51-9195', 'High school diploma or equivalent', 'None', 'Long-term on-the-job training']
# ['Paper goods machine setters, operators, and tenders', '51-9196', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Tire builders', '51-9197', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Helpers--production workers', '51-9198', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Production workers, all other', '51-9199', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Aircraft cargo handling supervisors', '53-1041', 'High school diploma or equivalent', 'Less than 5 years', 'None']
# ['First-line supervisors of transportation and material-moving workers, except aircraft cargo handling supervisors', '53-1047', 'High school diploma or equivalent', 'Less than 5 years', 'None']
# ['Airline pilots, copilots, and flight engineers', '53-2011', "Bachelor's degree", 'Less than 5 years', 'Moderate-term on-the-job training']
# ['Commercial pilots', '53-2012', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Air traffic controllers', '53-2021', "Associate's degree", 'None', 'Long-term on-the-job training']
# ['Airfield operations specialists', '53-2022', 'High school diploma or equivalent', 'None', 'Long-term on-the-job training']
# ['Flight attendants', '53-2031', 'High school diploma or equivalent', 'Less than 5 years', 'Moderate-term on-the-job training']
# ['Ambulance drivers and attendants, except emergency medical technicians', '53-3011', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Driver/sales workers', '53-3031', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Heavy and tractor-trailer truck drivers', '53-3032', 'Postsecondary nondegree award', 'None', 'Short-term on-the-job training']
# ['Light truck drivers', '53-3033', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Bus drivers, transit and intercity', '53-3052', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Passenger vehicle drivers, except bus drivers, transit and intercity', '53-3058', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Motor vehicle operators, all other', '53-3099', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Locomotive engineers', '53-4011', 'High school diploma or equivalent', 'Less than 5 years', 'Moderate-term on-the-job training']
# ['Rail yard engineers, dinkey operators, and hostlers', '53-4013', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Railroad brake, signal, and switch operators and locomotive firers', '53-4022', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Railroad conductors and yardmasters', '53-4031', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Subway and streetcar operators', '53-4041', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Rail transportation workers, all other', '53-4099', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Sailors and marine oilers', '53-5011', 'No formal educational credential', 'None', 'Moderate-term on-the-job training']
# ['Captains, mates, and pilots of water vessels', '53-5021', 'Postsecondary nondegree award', 'Less than 5 years', 'None']
# ['Motorboat operators', '53-5022', 'Postsecondary nondegree award', 'Less than 5 years', 'None']
# ['Ship engineers', '53-5031', 'Postsecondary nondegree award', 'Less than 5 years', 'None']
# ['Bridge and lock tenders', '53-6011', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Parking attendants', '53-6021', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Automotive and watercraft service attendants', '53-6031', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Traffic technicians', '53-6041', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Transportation inspectors', '53-6051', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Passenger attendants', '53-6061', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Aircraft service attendants and transportation workers, all other', '53-6098', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Conveyor operators and tenders', '53-7011', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Crane and tower operators', '53-7021', 'High school diploma or equivalent', 'Less than 5 years', 'Moderate-term on-the-job training']
# ['Dredge operators', '53-7031', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Hoist and winch operators', '53-7041', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Industrial truck and tractor operators', '53-7051', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Cleaners of vehicles and equipment', '53-7061', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Laborers and freight, stock, and material movers, hand', '53-7062', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Machine feeders and offbearers', '53-7063', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Packers and packagers, hand', '53-7064', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Stockers and order fillers', '53-7065', 'High school diploma or equivalent', 'None', 'Short-term on-the-job training']
# ['Gas compressor and gas pumping station operators', '53-7071', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Pump operators, except wellhead pumpers', '53-7072', 'High school diploma or equivalent', 'None', 'Moderate-term on-the-job training']
# ['Wellhead pumpers', '53-7073', 'High school diploma or equivalent', 'Less than 5 years', 'Moderate-term on-the-job training']
# ['Refuse and recyclable material collectors', '53-7081', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Tank car, truck, and ship loaders', '53-7121', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Material moving workers, all other', '53-7199', 'No formal educational credential', 'None', 'Short-term on-the-job training']
# ['Source: Employment Projections program, U.S. Bureau of Labor Statistics', None, None, None, None]
